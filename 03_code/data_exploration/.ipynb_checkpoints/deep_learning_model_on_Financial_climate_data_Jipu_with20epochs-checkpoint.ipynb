# %%
import pandas as pd

csv_path = "../../02_processed_data/FINAL_CLIMATE_FINANCIAL_DATA.csv"

# low_memory=False avoids the mixed-type warning during chunked inference
df = pd.read_csv(csv_path, low_memory=False)

print("Shape:", df.shape)

# show all columnsv
print("\nColumns:")
print(df.columns.tolist())

# show dtypes
print("\nDtypes:")
print(df.dtypes)

# quick missingness overview
missing = df.isna().mean().sort_values(ascending=False)
print("\nTop missingness (fraction):")
print(missing.head(15))

# %%
import random
import copy
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# -----------------------------
# 0) Repro + device
# -----------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -----------------------------
# 1) Load
# -----------------------------
csv_path = "../../02_processed_data/FINAL_CLIMATE_FINANCIAL_DATA.csv"
df = pd.read_csv(csv_path, low_memory=False)

# -----------------------------
# 2) Fix types
# -----------------------------
# real_gdp is object -> numeric
df["real_gdp"] = pd.to_numeric(df["real_gdp"], errors="coerce")

# If you want to confirm conversion:
print("real_gdp dtype:", df["real_gdp"].dtype, "missing:", df["real_gdp"].isna().mean())

# -----------------------------
# 3) Target + split by year
# -----------------------------
target = "hpi_change"

# drop rows missing target
df = df[df[target].notna()].copy()

train_df = df[(df["yr"] >= 2000) & (df["yr"] <= 2019)].copy()
test_df  = df[df["yr"] == 2020].copy()

print("Train shape:", train_df.shape, "years:", train_df["yr"].min(), "-", train_df["yr"].max())
print("Test shape :", test_df.shape, "years:", test_df["yr"].unique())

if len(test_df) == 0:
    raise ValueError("No 2020 rows found. Check df['yr'].")

# -----------------------------
# 4) Features
#   - numeric only
#   - exclude identifiers + target + yr
#   - exclude state (object)
# -----------------------------
numeric_cols = train_df.select_dtypes(include=[np.number]).columns.tolist()

exclude_cols = {
    target,
    "yr",
    "Unnamed: 0",     # row index
    "county_fips5",   # identifier
    "county_fips"     # identifier (float)
}

feature_cols = [c for c in numeric_cols if c not in exclude_cols]

print("\nNum features:", len(feature_cols))
print("Feature cols:", feature_cols)

X_train_full = train_df[feature_cols].values.astype(np.float32)
y_train_full = train_df[target].values.astype(np.float32).reshape(-1, 1)

X_test = test_df[feature_cols].values.astype(np.float32)
y_test = test_df[target].values.astype(np.float32).reshape(-1, 1)

# -----------------------------
# 5) Validation split from training years
# -----------------------------
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.15, random_state=SEED
)

# -----------------------------
# 6) Impute + scale (fit only on train)
# -----------------------------
imputer = SimpleImputer(strategy="median")
scaler = StandardScaler()

X_train_imp = imputer.fit_transform(X_train)
X_val_imp   = imputer.transform(X_val)
X_test_imp  = imputer.transform(X_test)

X_train_scaled = scaler.fit_transform(X_train_imp)
X_val_scaled   = scaler.transform(X_val_imp)
X_test_scaled  = scaler.transform(X_test_imp)

# -----------------------------
# 7) Torch dataset
# -----------------------------
class TabularAs1DDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float().unsqueeze(1)  # (N, 1, L)
        self.y = torch.from_numpy(y).float()               # (N, 1)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_ds = TabularAs1DDataset(X_train_scaled, y_train)
val_ds   = TabularAs1DDataset(X_val_scaled,   y_val)
test_ds  = TabularAs1DDataset(X_test_scaled,  y_test)

train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=256, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=256, shuffle=False)

# -----------------------------
# 8) Model
# -----------------------------
class HPI_CNN(nn.Module):
    def __init__(self, seq_len):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv1d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
        )
        with torch.no_grad():
            dummy = torch.zeros(1, 1, seq_len)
            out = self.conv(dummy)
            flat_size = out.view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Linear(flat_size, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

seq_len = X_train_scaled.shape[1]
model = HPI_CNN(seq_len).to(device)
print(model)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# -----------------------------
# 9) Train + early stopping
# -----------------------------
num_epochs = 20
patience = 4
min_delta = 1e-5

best_val = float("inf")
best_state = copy.deepcopy(model.state_dict())
no_improve = 0

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    model.eval()
    val_losses = []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            val_losses.append(loss.item())

    train_mse = float(np.mean(train_losses))
    val_mse = float(np.mean(val_losses))
    print(f"Epoch {epoch:03d} | train MSE {train_mse:.6f} | val MSE {val_mse:.6f}")

    if val_mse < best_val - min_delta:
        best_val = val_mse
        best_state = copy.deepcopy(model.state_dict())
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch} (best val MSE {best_val:.6f})")
            break

model.load_state_dict(best_state)

# -----------------------------
# 10) Evaluate on 2020 holdout
# -----------------------------
model.eval()
preds, trues = [], []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        yhat = model(xb).cpu().numpy()
        preds.append(yhat)
        trues.append(yb.numpy())

y_pred = np.vstack(preds).reshape(-1)
y_true = np.vstack(trues).reshape(-1)

mse  = mean_squared_error(y_true, y_pred)
rmse = float(np.sqrt(mse))
mae  = mean_absolute_error(y_true, y_pred)
r2   = r2_score(y_true, y_pred)

eps = 1e-8
mape = float(np.mean(np.abs((y_true - y_pred) / (np.abs(y_true) + eps))) * 100.0)
smape = float(np.mean(2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)) * 100.0)

print("\n===== 2020 HOLDOUT METRICS (target=hpi_change) =====")
print(f"N (2020) : {len(y_true)}")
print(f"MSE      : {mse:.6f}")
print(f"RMSE     : {rmse:.6f}")
print(f"MAE      : {mae:.6f}")
print(f"R^2      : {r2:.6f}")
print(f"MAPE %   : {mape:.3f}")
print(f"sMAPE %  : {smape:.3f}")

# -----------------------------
# 11) Save predictions
# -----------------------------
pred_df = test_df[["county_fips5", "state", "yr", target]].copy()
pred_df["y_pred"] = y_pred
pred_df["residual"] = pred_df[target] - pred_df["y_pred"]

pred_df.to_csv("predictions_2020.csv", index=False)
print("\nSaved predictions_2020.csv")
print(pred_df.head())
# Out:
# Device: cpu
# real_gdp dtype: float64 missing: 1.7469995283101274e-05
# Train shape: (54455, 23) years: 2000 - 2019
# Test shape : (2786, 23) years: [2020]
#
# Num features: 17
# Feature cols: ['index_nsa', 'flood_frequency', 'flood_property_damage', 'flood_duration_hours', 'heat_stress_index', 'drought_annual_mean_index', 'fire_frequency', 'fire_size', 'deaths_hurricane', 'injuries_hurricane', 'damage_hurricane', 'real_gdp', 'unemployment_rate', 'prop_rate', 'total_home_purchase', 'total_amt_purchase', 'total_population']
# HPI_CNN(
#   (conv): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): Conv1d(16, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (3): ReLU()
#     (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=256, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=1, bias=True)
# ...

# %%
import random
import copy
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# -----------------------------
# 0) Repro + device
# -----------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -----------------------------
# 1) Load
# -----------------------------
csv_path = "../../02_processed_data/FINAL_CLIMATE_FINANCIAL_DATA.csv"
df = pd.read_csv(csv_path, low_memory=False)

# Fix types
df["real_gdp"] = pd.to_numeric(df["real_gdp"], errors="coerce")

# Key columns
id_col = "county_fips5"
time_col = "yr"
target = "hpi_change"

# Drop rows missing essential fields
df = df[df[target].notna()].copy()
df = df[df[id_col].notna()].copy()
df = df[df[time_col].notna()].copy()

# Ensure sorted for temporal features
df = df.sort_values([id_col, time_col]).reset_index(drop=True)

# -----------------------------
# 2) Temporal feature engineering
# -----------------------------
def add_temporal_features(
    data: pd.DataFrame,
    group_col: str,
    time_col: str,
    target_col: str,
    extra_lag_cols=None,
    lags=(1, 2, 3),
    roll_windows=(3, 5),
) -> pd.DataFrame:
    """
    Creates lag/ momentum / rolling stats features per group.
    - Lags are created for target and optionally additional columns.
    - Momentum and acceleration based on target lags.
    """
    if extra_lag_cols is None:
        extra_lag_cols = []

    out = data.copy()
    g = out.groupby(group_col, sort=False)

    # --- target lags ---
    for k in lags:
        out[f"{target_col}_lag{k}"] = g[target_col].shift(k)

    # --- momentum (trend) and acceleration ---
    # use lagged changes so that for year t we only use <= t-1 information
    # momentum at t: (y_{t-1} - y_{t-2})
    out[f"{target_col}_mom1"] = out[f"{target_col}_lag1"] - out[f"{target_col}_lag2"]

    # acceleration at t: (y_{t-1}-y_{t-2}) - (y_{t-2}-y_{t-3})
    out[f"{target_col}_acc1"] = (
        (out[f"{target_col}_lag1"] - out[f"{target_col}_lag2"])
        - (out[f"{target_col}_lag2"] - out[f"{target_col}_lag3"])
    )

    # --- rolling stats of target (use past values only by shifting first) ---
    # roll mean/std of last W years up to t-1
    shifted_target = g[target_col].shift(1)
    for w in roll_windows:
        out[f"{target_col}_roll{w}_mean"] = shifted_target.groupby(out[group_col]).rolling(w).mean().reset_index(level=0, drop=True)
        out[f"{target_col}_roll{w}_std"]  = shifted_target.groupby(out[group_col]).rolling(w).std().reset_index(level=0, drop=True)

    # --- optional lags for other covariates (e.g., index_nsa, unemployment_rate) ---
    for col in extra_lag_cols:
        for k in (1, 2):
            out[f"{col}_lag{k}"] = g[col].shift(k)

    return out

# Choose a couple additional temporal covariates (optional but often helpful)
extra_lag_cols = ["index_nsa", "unemployment_rate", "prop_rate", "real_gdp"]

df_fe = add_temporal_features(
    df,
    group_col=id_col,
    time_col=time_col,
    target_col=target,
    extra_lag_cols=extra_lag_cols,
    lags=(1, 2, 3),
    roll_windows=(3, 5),
)

# Drop rows where key lag features are missing (early years per county)
required = [f"{target}_lag1", f"{target}_lag2", f"{target}_lag3"]
df_fe = df_fe.dropna(subset=required).copy()

print("After temporal FE:", df_fe.shape)

# -----------------------------
# 3) Time-aware split: train 2000-2017, val 2018-2019, test 2020
# -----------------------------
train_df = df_fe[(df_fe[time_col] >= 2000) & (df_fe[time_col] <= 2017)].copy()
val_df   = df_fe[(df_fe[time_col] >= 2018) & (df_fe[time_col] <= 2019)].copy()
test_df  = df_fe[df_fe[time_col] == 2020].copy()

print("Train:", train_df.shape, "Val:", val_df.shape, "Test:", test_df.shape)
if len(test_df) == 0:
    raise ValueError("No 2020 rows after lag feature creation (need earlier years per county).")

# -----------------------------
# 4) Feature selection (numeric only, exclude IDs/time/target)
# -----------------------------
numeric_cols = train_df.select_dtypes(include=[np.number]).columns.tolist()
exclude = {target, time_col, "Unnamed: 0", "county_fips5", "county_fips"}  # keep ID columns out
feature_cols = [c for c in numeric_cols if c not in exclude]

print("Num features:", len(feature_cols))
print("Sample engineered features:", [c for c in feature_cols if "lag" in c or "mom" in c or "roll" in c][:15])

X_train = train_df[feature_cols].values.astype(np.float32)
y_train = train_df[target].values.astype(np.float32).reshape(-1, 1)

X_val = val_df[feature_cols].values.astype(np.float32)
y_val = val_df[target].values.astype(np.float32).reshape(-1, 1)

X_test = test_df[feature_cols].values.astype(np.float32)
y_test = test_df[target].values.astype(np.float32).reshape(-1, 1)

# -----------------------------
# 5) Impute + scale (fit only on train)
# -----------------------------
imputer = SimpleImputer(strategy="median")
scaler = StandardScaler()

X_train_imp = imputer.fit_transform(X_train)
X_val_imp   = imputer.transform(X_val)
X_test_imp  = imputer.transform(X_test)

X_train_scaled = scaler.fit_transform(X_train_imp)
X_val_scaled   = scaler.transform(X_val_imp)
X_test_scaled  = scaler.transform(X_test_imp)

# -----------------------------
# 6) Torch dataset
# -----------------------------
class TabularAs1DDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float().unsqueeze(1)  # (N, 1, L)
        self.y = torch.from_numpy(y).float()               # (N, 1)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_loader = DataLoader(TabularAs1DDataset(X_train_scaled, y_train), batch_size=128, shuffle=True)
val_loader   = DataLoader(TabularAs1DDataset(X_val_scaled,   y_val),   batch_size=256, shuffle=False)
test_loader  = DataLoader(TabularAs1DDataset(X_test_scaled,  y_test),  batch_size=256, shuffle=False)

# -----------------------------
# 7) CNN model (same as yours)
# -----------------------------
class HPI_CNN(nn.Module):
    def __init__(self, seq_len):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv1d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
        )
        with torch.no_grad():
            dummy = torch.zeros(1, 1, seq_len)
            out = self.conv(dummy)
            flat_size = out.view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Linear(flat_size, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

model = HPI_CNN(seq_len=X_train_scaled.shape[1]).to(device)

# Robust loss often helps when 2020 has outliers/regime shift
criterion = nn.SmoothL1Loss(beta=1.0)   # Huber loss (more robust than MSE)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# -----------------------------
# 8) Train + early stopping
# -----------------------------
num_epochs = 20
patience = 4
min_delta = 1e-5

best_val = float("inf")
best_state = copy.deepcopy(model.state_dict())
no_improve = 0

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    model.eval()
    val_losses = []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            val_losses.append(loss.item())

    train_loss = float(np.mean(train_losses))
    val_loss = float(np.mean(val_losses))
    print(f"Epoch {epoch:03d} | train loss {train_loss:.6f} | val loss {val_loss:.6f}")

    if val_loss < best_val - min_delta:
        best_val = val_loss
        best_state = copy.deepcopy(model.state_dict())
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch} (best val loss {best_val:.6f})")
            break

model.load_state_dict(best_state)

# -----------------------------
# 9) Evaluate on 2020
# -----------------------------
model.eval()
preds, trues = [], []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        yhat = model(xb).cpu().numpy()
        preds.append(yhat)
        trues.append(yb.numpy())

y_pred = np.vstack(preds).reshape(-1)
y_true = np.vstack(trues).reshape(-1)

mse  = mean_squared_error(y_true, y_pred)
rmse = float(np.sqrt(mse))
mae  = mean_absolute_error(y_true, y_pred)
r2   = r2_score(y_true, y_pred)

# MAPE can blow up when y≈0; compute masked MAPE + sMAPE
eps = 1e-8
smape = float(np.mean(2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)) * 100.0)
mask = np.abs(y_true) > 0.5
mape_masked = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / (y_true[mask] + eps))) * 100.0)

print("\n===== 2020 HOLDOUT METRICS with temporal terms =====")
print(f"N (2020) : {len(y_true)}")
print(f"MSE      : {mse:.6f}")
print(f"RMSE     : {rmse:.6f}")
print(f"MAE      : {mae:.6f}")
print(f"R^2      : {r2:.6f}")
print(f"sMAPE %  : {smape:.3f}")
print(f"MAPE% on |y|>0.5 : {mape_masked:.3f} (kept {mask.mean():.1%} of rows)")

# Save predictions
pred_out = test_df[[id_col, "state", time_col, target]].copy()
pred_out["y_pred"] = y_pred
pred_out["residual"] = pred_out[target] - pred_out["y_pred"]
pred_out.to_csv("predictions_2020_with_temporal.csv", index=False)
print("Saved predictions_2020_with_temporal.csv")
# Out:
# Device: cpu
# After temporal FE: (48903, 40)
# Train: (40582, 40) Val: (5546, 40) Test: (2775, 40)
# Num features: 34
# Sample engineered features: ['hpi_change_lag1', 'hpi_change_lag2', 'hpi_change_lag3', 'hpi_change_mom1', 'hpi_change_roll3_mean', 'hpi_change_roll3_std', 'hpi_change_roll5_mean', 'hpi_change_roll5_std', 'index_nsa_lag1', 'index_nsa_lag2', 'unemployment_rate_lag1', 'unemployment_rate_lag2', 'prop_rate_lag1', 'prop_rate_lag2', 'real_gdp_lag1']
# Epoch 001 | train loss 2.904394 | val loss 2.337666
# Epoch 002 | train loss 2.482314 | val loss 2.285468
# Epoch 003 | train loss 2.317542 | val loss 2.453749
# Epoch 004 | train loss 2.165939 | val loss 2.256769
# Epoch 005 | train loss 2.013056 | val loss 1.942780
# Epoch 006 | train loss 1.794832 | val loss 1.823038
# Epoch 007 | train loss 1.528682 | val loss 1.319578
# Epoch 008 | train loss 1.204265 | val loss 1.264108
# Epoch 009 | train loss 0.957095 | val loss 0.860604
# ...

# %%
import numpy as np
import pandas as pd

# sign labels: 1 if positive, 0 if <= 0
y_true_pos = (y_true > 0).astype(int)
y_pred_pos = (y_pred > 0).astype(int)

TP = int(((y_true_pos == 1) & (y_pred_pos == 1)).sum())  # predicted +, actual +
TN = int(((y_true_pos == 0) & (y_pred_pos == 0)).sum())  # predicted -, actual -
FP = int(((y_true_pos == 0) & (y_pred_pos == 1)).sum())  # predicted +, actual -
FN = int(((y_true_pos == 1) & (y_pred_pos == 0)).sum())  # predicted -, actual +

acc = (TP + TN) / len(y_true_pos)
pos_precision = TP / (TP + FP + 1e-12)
pos_recall    = TP / (TP + FN + 1e-12)

print("=== Direction (sign) results for 2020 ===")
print(f"TP (pred +, actual +): {TP}")
print(f"FP (pred +, actual -): {FP}")
print(f"FN (pred -, actual +): {FN}")
print(f"TN (pred -, actual -): {TN}")
print(f"Directional accuracy  : {acc:.3f}")
print(f"Positive precision    : {pos_precision:.3f}")
print(f"Positive recall       : {pos_recall:.3f}")

# If you also want counts of actual/pred positives
print("\nCounts:")
print("Actual positives:", int(y_true_pos.sum()))
print("Pred positives  :", int(y_pred_pos.sum()))
# Out:
# === Direction (sign) results for 2020 ===
# TP (pred +, actual +): 2504
# FP (pred +, actual -): 50
# FN (pred -, actual +): 26
# TN (pred -, actual -): 195
# Directional accuracy  : 0.973
# Positive precision    : 0.980
# Positive recall       : 0.990
#
# Counts:
# Actual positives: 2530
# Pred positives  : 2554

# %%
abs_err = np.abs(y_true - y_pred)
print("Abs error percentiles:",
      np.percentile(abs_err, [50, 75, 90, 95, 99, 99.5, 99.9]))
print("Max abs error:", abs_err.max())
# Out:
# Abs error percentiles: [ 0.40649033  0.73193324  1.18686621  1.57414244  3.97523852 10.37334772
#  66.9438669 ]
# Max abs error: 132.3222

# %%
pred_out = test_df[["county_fips5", "state", "yr", target]].copy()
pred_out["y_pred"] = y_pred
pred_out["abs_err"] = np.abs(pred_out[target] - pred_out["y_pred"])
print(pred_out.sort_values("abs_err", ascending=False).head(20))
# Out:
#        county_fips5         state    yr  hpi_change      y_pred     abs_err
# 34438         36061      NEW YORK  2020        0.00  132.322205  132.322205
# 29746         29181      MISSOURI  2020        0.00   86.344238   86.344238
# 19472         21105      KENTUCKY  2020        0.00   72.407295   72.407295
# 33778         35059    NEW MEXICO  2020        0.00   65.348602   65.348602
# 53049         51595      VIRGINIA  2020       -2.60   52.339680   54.939680
# 16744         19177          IOWA  2020        0.00   53.950115   53.950115
# 4480           8011      COLORADO  2020        0.00   51.568604   51.568604
# 4602           8025      COLORADO  2020        0.00   50.032883   50.032883
# 8693          13165       GEORGIA  2020       -3.51   46.380280   49.890280
# 1980           5021      ARKANSAS  2020        0.00   48.167534   48.167534
# 8962          13197       GEORGIA  2020        0.00   45.872105   45.872105
# ...

# %%
# how many exact zeros in 2020?
z = (test_df[target] == 0).mean()
print("Fraction of hpi_change == 0 in 2020:", z)

# compare distribution excluding zeros
print("2020 target describe:")
print(test_df[target].describe())
print("\n2020 target describe (non-zero only):")
print(test_df.loc[test_df[target] != 0, target].describe())
# Out:
# Fraction of hpi_change == 0 in 2020: 0.003963963963963964
# 2020 target describe:
# count    2775.000000
# mean        3.525539
# std         3.097909
# min       -18.260000
# 25%         2.110000
# 50%         3.550000
# 75%         5.030000
# max        30.040000
# Name: hpi_change, dtype: float64
#
# 2020 target describe (non-zero only):
# count    2764.000000
# mean        3.539569
# std         3.096057
# min       -18.260000
# 25%         2.120000
# 50%         3.555000
# 75%         5.040000
# max        30.040000
# Name: hpi_change, dtype: float64

# %%
import pandas as pd
import numpy as np

id_col = "county_fips5"
time_col = "yr"
target = "hpi_change"

# rows in 2020 with exact zero target
zeros_2020 = df[(df[time_col] == 2020) & (df[target] == 0)].copy()

print("Zeros in 2020:", zeros_2020.shape[0])
print("Unique counties with zero in 2020:", zeros_2020[id_col].nunique())

# show a few
display_cols = [id_col, "state", time_col, target, "index_nsa", "real_gdp", "unemployment_rate", "prop_rate"]
print(zeros_2020[display_cols].head(20))
# Out:
# Zeros in 2020: 21
# Unique counties with zero in 2020: 21
#        county_fips5         state    yr  hpi_change  index_nsa     real_gdp  \
# 1980           5021      ARKANSAS  2020         0.0     157.88     334367.0
# 4480           8011      COLORADO  2020         0.0     159.29     125877.0
# 4602           8025      COLORADO  2020         0.0     131.69     116813.0
# 4666           8033      COLORADO  2020         0.0     100.00      99972.0
# 7588          13049       GEORGIA  2020         0.0     100.00     194800.0
# 8962          13197       GEORGIA  2020         0.0     129.33     118030.0
# 9750          13289       GEORGIA  2020         0.0     115.43     249719.0
# 11160         17021      ILLINOIS  2020         0.0     203.46    1345763.0
# 16744         19177          IOWA  2020         0.0     152.04     211246.0
# 19472         21105      KENTUCKY  2020         0.0     139.15     139460.0
# 29746         29181      MISSOURI  2020         0.0     156.78     206570.0
# ...

# %%
zero_counties = zeros_2020[id_col].unique()

hist = (
    df[df[id_col].isin(zero_counties)]
    .groupby(id_col)
    .agg(
        state=("state", "first"),
        n_years=(time_col, "nunique"),
        year_min=(time_col, "min"),
        year_max=(time_col, "max"),
        n_obs=(target, "size"),
        n_zero=(target, lambda s: int((s == 0).sum())),
        pct_zero=(target, lambda s: float((s == 0).mean())),
        n_nonzero=(target, lambda s: int((s != 0).sum())),
        mean_nonzero=(target, lambda s: float(s[s != 0].mean()) if (s != 0).any() else np.nan),
        std_nonzero=(target, lambda s: float(s[s != 0].std()) if (s != 0).any() else np.nan),
    )
    .reset_index()
    .sort_values(["pct_zero", "n_zero"], ascending=False)
)

print("Summary for counties that are zero in 2020:")
print(hist.head(30))
# Out:
# Summary for counties that are zero in 2020:
#     county_fips5          state  n_years  year_min  year_max  n_obs  n_zero  \
# 3           8033       COLORADO        1      2020      2020      1       1
# 4          13049        GEORGIA        1      2020      2020      1       1
# 11         31169       NEBRASKA        1      2020      2020      1       1
# 12         32017         NEVADA        1      2020      2020      1       1
# 15         38025   NORTH DAKOTA        1      2020      2020      1       1
# 16         38103   NORTH DAKOTA        1      2020      2020      1       1
# 17         42113   PENNSYLVANIA        1      2020      2020      1       1
# 18         46025   SOUTH DAKOTA        1      2020      2020      1       1
# 19         46043   SOUTH DAKOTA        1      2020      2020      1       1
# 20         54023  WEST VIRGINIA        1      2020      2020      1       1
# 2           8025       COLORADO       20      2001      2020     20      11
# ...

# %%
# pick top 5 most suspicious (most zeros)
sus = hist.head(5)[id_col].tolist()

for c in sus:
    ts = df[df[id_col] == c].sort_values(time_col)[[id_col, "state", time_col, target, "index_nsa"]]
    print("\n==== county:", c, "state:", ts["state"].iloc[0], "====")
    print(ts.to_string(index=False))
# Out:
# ==== county: 8033 state: COLORADO ====
#  county_fips5    state   yr  hpi_change  index_nsa
#          8033 COLORADO 2020         0.0      100.0
#
# ==== county: 13049 state: GEORGIA ====
#  county_fips5   state   yr  hpi_change  index_nsa
#         13049 GEORGIA 2020         0.0      100.0
#
# ==== county: 31169 state: NEBRASKA ====
#  county_fips5    state   yr  hpi_change  index_nsa
#         31169 NEBRASKA 2020         0.0      100.0
#
# ==== county: 32017 state: NEVADA ====
#  county_fips5  state   yr  hpi_change  index_nsa
#         32017 NEVADA 2020         0.0      100.0
#
# ==== county: 38025 state: NORTH DAKOTA ====
#  county_fips5        state   yr  hpi_change  index_nsa
#         38025 NORTH DAKOTA 2020         0.0      100.0

# %%
zeros_by_year = (
    df.assign(is_zero=(df[target] == 0).astype(int))
      .groupby(time_col)["is_zero"]
      .agg(n="size", n_zero="sum", pct_zero="mean")
      .reset_index()
      .sort_values("pct_zero", ascending=False)
)

print(zeros_by_year.head(25))
# Out:
#       yr     n  n_zero  pct_zero
# 1   2001  2579     165  0.063978
# 3   2003  2713      81  0.029856
# 2   2002  2633      54  0.020509
# 9   2009  2761      24  0.008693
# 16  2016  2774      22  0.007931
# 20  2020  2786      21  0.007538
# 15  2015  2772      16  0.005772
# 7   2007  2740      15  0.005474
# 19  2019  2776      15  0.005403
# 12  2012  2767      13  0.004698
# 17  2017  2775      13  0.004685
# 18  2018  2776      13  0.004683
# 13  2013  2772      12  0.004329
# 6   2006  2728      11  0.004032
# 0   2000  2417       9  0.003724
# 14  2014  2772      10  0.003608
# 11  2011  2762       9  0.003259
# 8   2008  2742       6  0.002188
# 10  2010  2762       6  0.002172
# 5   2005  2719       4  0.001471
# 4   2004  2715       3  0.001105

# %%
df_2020 = df[df[time_col] == 2020].copy()
zero_mask = (df_2020[target] == 0)

cols_check = ["index_nsa", "real_gdp", "unemployment_rate", "prop_rate", "total_population"]

summary_compare = pd.DataFrame({
    "mean_zero_y": df_2020.loc[zero_mask, cols_check].mean(),
    "mean_nonzero_y": df_2020.loc[~zero_mask, cols_check].mean(),
    "std_zero_y": df_2020.loc[zero_mask, cols_check].std(),
    "std_nonzero_y": df_2020.loc[~zero_mask, cols_check].std(),
})
print(summary_compare)
# Out:
#                     mean_zero_y  mean_nonzero_y    std_zero_y  std_nonzero_y
# index_nsa          1.404848e+02    3.343599e+02  8.230987e+01   2.394467e+02
# real_gdp           3.472667e+07    6.885559e+06  1.576328e+08   2.671717e+07
# unemployment_rate  5.504762e+00    6.852694e+00  1.905381e+00   2.117926e+00
# prop_rate          2.429830e-01    3.572730e-01  6.257304e-01   8.425553e-01
# total_population   8.748643e+04    1.173489e+05  3.648631e+05   3.534783e+05

# %%
min_years = 10

county_year_counts = df.groupby("county_fips5")["yr"].nunique()
good_counties = county_year_counts[county_year_counts >= min_years].index

df_clean = df[df["county_fips5"].isin(good_counties)].copy()
print("Kept rows:", df_clean.shape, "Kept counties:", len(good_counties))
# Out:
# Kept rows: (57129, 23) Kept counties: 2762

# %%
max_zero_frac = 0.20  # tune: 0.05, 0.10, 0.20

zero_frac = df_clean.groupby("county_fips5")["hpi_change"].apply(lambda s: (s == 0).mean())
good_counties2 = zero_frac[zero_frac <= max_zero_frac].index

df_clean = df_clean[df_clean["county_fips5"].isin(good_counties2)].copy()
print("After zero-filter rows:", df_clean.shape, "counties:", len(good_counties2))
# Out:
# After zero-filter rows: (56900, 23) counties: 2749

# %%
import random
import copy
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# -----------------------------
# 0) Repro + device
# -----------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# -----------------------------
# 1) Load
# -----------------------------
csv_path = "../../02_processed_data/FINAL_CLIMATE_FINANCIAL_DATA.csv"
df = pd.read_csv(csv_path, low_memory=False)

# Fix types
df["real_gdp"] = pd.to_numeric(df["real_gdp"], errors="coerce")

# Key columns
id_col = "county_fips5"
time_col = "yr"
target = "hpi_change"

# Drop rows missing essential fields
df = df[df[target].notna()].copy()
df = df[df[id_col].notna()].copy()
df = df[df[time_col].notna()].copy()

# -----------------------------
# 1.5) CLEAN: drop "bad counties" (short histories / too many zero targets)
# -----------------------------
# (A) require a minimum number of distinct years per county
min_years = 10
county_years = df.groupby(id_col)[time_col].nunique()
good_by_years = county_years[county_years >= min_years].index
df_clean = df[df[id_col].isin(good_by_years)].copy()

# (B) remove counties with too many exact-zero targets (often placeholders)
max_zero_frac = 0.10
zero_frac = df_clean.groupby(id_col)[target].apply(lambda s: (s == 0).mean())
good_by_zero = zero_frac[zero_frac <= max_zero_frac].index
df_clean = df_clean[df_clean[id_col].isin(good_by_zero)].copy()

print("df original:", df.shape, "| unique counties:", df[id_col].nunique())
print("df_clean   :", df_clean.shape, "| unique counties:", df_clean[id_col].nunique())

# Optional: treat index_nsa==100 as suspicious placeholder and impute later
# (comment out if you believe 100 is a legitimate base)
df_clean.loc[df_clean["index_nsa"] == 100, "index_nsa"] = np.nan

# Ensure sorted for temporal features
df_clean = df_clean.sort_values([id_col, time_col]).reset_index(drop=True)

# -----------------------------
# 2) Temporal feature engineering
# -----------------------------
def add_temporal_features(
    data: pd.DataFrame,
    group_col: str,
    time_col: str,
    target_col: str,
    extra_lag_cols=None,
    lags=(1, 2, 3),
    roll_windows=(3, 5),
) -> pd.DataFrame:
    """
    Creates lag/ momentum / rolling stats features per group.
    - Lags are created for target and optionally additional columns.
    - Momentum and acceleration based on target lags.
    """
    if extra_lag_cols is None:
        extra_lag_cols = []

    out = data.copy()
    g = out.groupby(group_col, sort=False)

    # --- target lags ---
    for k in lags:
        out[f"{target_col}_lag{k}"] = g[target_col].shift(k)

    # --- momentum (trend) and acceleration ---
    out[f"{target_col}_mom1"] = out[f"{target_col}_lag1"] - out[f"{target_col}_lag2"]
    out[f"{target_col}_acc1"] = (
        (out[f"{target_col}_lag1"] - out[f"{target_col}_lag2"])
        - (out[f"{target_col}_lag2"] - out[f"{target_col}_lag3"])
    )

    # --- rolling stats of target (use past values only by shifting first) ---
    shifted_target = g[target_col].shift(1)
    for w in roll_windows:
        out[f"{target_col}_roll{w}_mean"] = (
            shifted_target.groupby(out[group_col]).rolling(w).mean().reset_index(level=0, drop=True)
        )
        out[f"{target_col}_roll{w}_std"] = (
            shifted_target.groupby(out[group_col]).rolling(w).std().reset_index(level=0, drop=True)
        )

    # --- optional lags for other covariates ---
    for col in extra_lag_cols:
        for k in (1, 2):
            out[f"{col}_lag{k}"] = g[col].shift(k)

    return out

extra_lag_cols = ["index_nsa", "unemployment_rate", "prop_rate", "real_gdp"]

df_fe = add_temporal_features(
    df_clean,
    group_col=id_col,
    time_col=time_col,
    target_col=target,
    extra_lag_cols=extra_lag_cols,
    lags=(1, 2, 3),
    roll_windows=(3, 5),
)

# Drop rows where key lag features are missing (early years per county)
required = [f"{target}_lag1", f"{target}_lag2", f"{target}_lag3"]
df_fe = df_fe.dropna(subset=required).copy()

print("After temporal FE:", df_fe.shape)

# -----------------------------
# 3) Time-aware split: train 2000-2017, val 2018-2019, test 2020
# -----------------------------
train_df = df_fe[(df_fe[time_col] >= 2000) & (df_fe[time_col] <= 2017)].copy()
val_df   = df_fe[(df_fe[time_col] >= 2018) & (df_fe[time_col] <= 2019)].copy()
test_df  = df_fe[df_fe[time_col] == 2020].copy()

print("Train:", train_df.shape, "Val:", val_df.shape, "Test:", test_df.shape)
if len(test_df) == 0:
    raise ValueError("No 2020 rows after cleaning + lag feature creation.")

# -----------------------------
# 4) Feature selection (numeric only, exclude IDs/time/target)
# -----------------------------
numeric_cols = train_df.select_dtypes(include=[np.number]).columns.tolist()
exclude = {target, time_col, "Unnamed: 0", "county_fips5", "county_fips"}
feature_cols = [c for c in numeric_cols if c not in exclude]

print("Num features:", len(feature_cols))
print("Sample engineered features:", [c for c in feature_cols if "lag" in c or "mom" in c or "roll" in c][:15])

X_train = train_df[feature_cols].values.astype(np.float32)
y_train = train_df[target].values.astype(np.float32).reshape(-1, 1)

X_val = val_df[feature_cols].values.astype(np.float32)
y_val = val_df[target].values.astype(np.float32).reshape(-1, 1)

X_test = test_df[feature_cols].values.astype(np.float32)
y_test = test_df[target].values.astype(np.float32).reshape(-1, 1)

# -----------------------------
# 5) Impute + scale (fit only on train)
# -----------------------------
imputer = SimpleImputer(strategy="median")
scaler = StandardScaler()

X_train_imp = imputer.fit_transform(X_train)
X_val_imp   = imputer.transform(X_val)
X_test_imp  = imputer.transform(X_test)

X_train_scaled = scaler.fit_transform(X_train_imp)
X_val_scaled   = scaler.transform(X_val_imp)
X_test_scaled  = scaler.transform(X_test_imp)

# -----------------------------
# 6) Torch dataset
# -----------------------------
class TabularAs1DDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float().unsqueeze(1)  # (N, 1, L)
        self.y = torch.from_numpy(y).float()               # (N, 1)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_loader = DataLoader(TabularAs1DDataset(X_train_scaled, y_train), batch_size=128, shuffle=True)
val_loader   = DataLoader(TabularAs1DDataset(X_val_scaled,   y_val),   batch_size=256, shuffle=False)
test_loader  = DataLoader(TabularAs1DDataset(X_test_scaled,  y_test),  batch_size=256, shuffle=False)

# -----------------------------
# 7) CNN model
# -----------------------------
class HPI_CNN(nn.Module):
    def __init__(self, seq_len, y_scale=None):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv1d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
        )
        with torch.no_grad():
            dummy = torch.zeros(1, 1, seq_len)
            out = self.conv(dummy)
            flat_size = out.view(1, -1).shape[1]

        self.fc1 = nn.Sequential(nn.Linear(flat_size, 64), nn.ReLU())
        self.out = nn.Linear(64, 1)

        # Optional bounded output (helps prevent insane predictions)
        self.y_scale = y_scale  # if None, unbounded output

    def forward(self, x):
        x = self.conv(x).view(x.size(0), -1)
        x = self.fc1(x)
        x = self.out(x)
        if self.y_scale is not None:
            x = torch.tanh(x) * self.y_scale
        return x

# set y_scale from train distribution (99th percentile abs value)
y_scale = float(np.percentile(np.abs(y_train), 99))
print("Using bounded output with y_scale =", y_scale)

model = HPI_CNN(seq_len=X_train_scaled.shape[1], y_scale=y_scale).to(device)

criterion = nn.SmoothL1Loss(beta=1.0)  # Huber
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# -----------------------------
# 8) Train + early stopping
# -----------------------------
num_epochs = 30
patience = 6
min_delta = 1e-5

best_val = float("inf")
best_state = copy.deepcopy(model.state_dict())
no_improve = 0

for epoch in range(1, num_epochs + 1):
    model.train()
    train_losses = []
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())

    model.eval()
    val_losses = []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            pred = model(xb)
            loss = criterion(pred, yb)
            val_losses.append(loss.item())

    train_loss = float(np.mean(train_losses))
    val_loss = float(np.mean(val_losses))
    print(f"Epoch {epoch:03d} | train loss {train_loss:.6f} | val loss {val_loss:.6f}")

    if val_loss < best_val - min_delta:
        best_val = val_loss
        best_state = copy.deepcopy(model.state_dict())
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch} (best val loss {best_val:.6f})")
            break

model.load_state_dict(best_state)

# -----------------------------
# 9) Evaluate on 2020 + SIGN ACCURACY
# -----------------------------
model.eval()
preds, trues = [], []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        yhat = model(xb).cpu().numpy()
        preds.append(yhat)
        trues.append(yb.numpy())

y_pred = np.vstack(preds).reshape(-1)
y_true = np.vstack(trues).reshape(-1)

mse  = mean_squared_error(y_true, y_pred)
rmse = float(np.sqrt(mse))
mae  = mean_absolute_error(y_true, y_pred)
r2   = r2_score(y_true, y_pred)

eps = 1e-8
smape = float(np.mean(2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)) * 100.0)

print("\n===== 2020 HOLDOUT METRICS (df_clean) =====")
print(f"N (2020) : {len(y_true)}")
print(f"MSE      : {mse:.6f}")
print(f"RMSE     : {rmse:.6f}")
print(f"MAE      : {mae:.6f}")
print(f"R^2      : {r2:.6f}")
print(f"sMAPE %  : {smape:.3f}")

# Save predictions + direction correctness
pred_out = test_df[[id_col, "state", time_col, target]].copy()
pred_out["y_pred"] = y_pred
pred_out["residual"] = pred_out[target] - pred_out["y_pred"]
pred_out["abs_err"] = np.abs(pred_out["residual"])

pred_out["actual_pos"] = (pred_out[target] > 0).astype(int)
pred_out["pred_pos"]   = (pred_out["y_pred"] > 0).astype(int)

TP = int(((pred_out["actual_pos"] == 1) & (pred_out["pred_pos"] == 1)).sum())
TN = int(((pred_out["actual_pos"] == 0) & (pred_out["pred_pos"] == 0)).sum())
FP = int(((pred_out["actual_pos"] == 0) & (pred_out["pred_pos"] == 1)).sum())
FN = int(((pred_out["actual_pos"] == 1) & (pred_out["pred_pos"] == 0)).sum())

direction_acc = (TP + TN) / len(pred_out)
pos_precision = TP / (TP + FP + 1e-12)
pos_recall    = TP / (TP + FN + 1e-12)

print("\n===== 2020 SIGN / DIRECTION RESULTS (df_clean) =====")
print(f"TP (pred +, actual +): {TP}")
print(f"FP (pred +, actual -): {FP}")
print(f"FN (pred -, actual +): {FN}")
print(f"TN (pred -, actual -): {TN}")
print(f"Directional accuracy  : {direction_acc:.3f}")
print(f"Positive precision    : {pos_precision:.3f}")
print(f"Positive recall       : {pos_recall:.3f}")

pred_out.to_csv("predictions_2020_df_clean.csv", index=False)
print("\nSaved predictions_2020_df_clean.csv")

print("\nTop 20 worst abs errors (2020, df_clean):")
print(pred_out.sort_values("abs_err", ascending=False).head(20))
# Out:
#        Unnamed: 0  county_fips5    yr  hpi_change  index_nsa    state  \
# 0              14          1001  2000        2.50     141.23  ALABAMA
# 1              15          1001  2001        3.44     146.08  ALABAMA
# 2              16          1001  2002        2.67     149.98  ALABAMA
# 3              17          1001  2003        1.79     152.66  ALABAMA
# 4              18          1001  2004        2.92     157.12  ALABAMA
# ...           ...           ...   ...         ...        ...      ...
# 57236      103285         56045  2016        1.50     207.30  WYOMING
# 57237      103286         56045  2017        0.99     209.35  WYOMING
# 57238      103287         56045  2018       -1.00     207.26  WYOMING
# 57239      103288         56045  2019        8.55     224.99  WYOMING
# 57240      103289         56045  2020        4.45     235.01  WYOMING
#
#        flood_frequency  flood_property_damage  flood_duration_hours  \
# ...
