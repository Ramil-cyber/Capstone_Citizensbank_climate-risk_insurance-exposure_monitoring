# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Get the flood dataset

# %%
# MERGED TWICE TO REMOVE DUPLICATES

flood_county = pd.read_csv(
    "../../02_processed_data/fema_flood_county_2000.csv"
).reset_index(drop=True)
flood_county.sort_values(by=["FIPS", "YEAR"]).dropna()
print(flood_county.info())
print(flood_county.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35450 entries, 0 to 35449
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS                   35450 non-null  int64
#  1   YEAR                   35450 non-null  int64
#  2   STATE                  35450 non-null  object
#  3   CZ_NAME                35450 non-null  object
#  4   COUNT                  35450 non-null  int64
#  5   TOTAL_DAMAGE_PROPERTY  35450 non-null  float64
#  6   TOTAL_DURATION_HOURS   35450 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.9+ MB
# None
#                FIPS          YEAR         COUNT  TOTAL_DAMAGE_PROPERTY  \
# count  35450.000000  35450.000000  35450.000000           3.545000e+04
# mean   30434.366008   2010.019069     13.039126           3.367555e+06
# std    14880.622613      6.061159     18.316309           1.256051e+08
# min     1001.000000   2000.000000      1.000000           0.000000e+00
# 25%    19083.000000   2005.000000      2.000000           0.000000e+00
# 50%    29145.000000   2010.000000      6.000000           1.000000e+03
# 75%    45025.000000   2015.000000     16.000000           7.000000e+04
# max    56045.000000   2020.000000    194.000000           1.000051e+10
#
#        TOTAL_DURATION_HOURS
# count          35450.000000
# mean             118.446200
# std              517.895344
# min                0.000000
# 25%                3.000000
# 50%                9.000000
# 75%               41.392500
# max            22776.570000

# %% [markdown]
# #### Get the HPI dataset

# %%
hpi_county = pd.read_csv("../../02_processed_data/hpi_county_2000.csv")
hpi_county.sort_values(by=["county_fips5", "yr"]).dropna()
print(hpi_county.info())
print(hpi_county.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21965 entries, 0 to 21964
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cbsa_code                 21965 non-null  int64
#  1   cbsa_title                21965 non-null  object
#  2   county_fips5              21965 non-null  int64
#  3   county/county_equivalent  21965 non-null  object
#  4   state_name                21965 non-null  object
#  5   place_name                21965 non-null  object
#  6   place_id                  21965 non-null  int64
#  7   yr                        21965 non-null  int64
#  8   index_nsa                 21965 non-null  float64
#  9   index_prev                21965 non-null  float64
#  10  hpi_change                21965 non-null  float64
#  11  hpi_yoy                   21965 non-null  float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 2.0+ MB
# None
#           cbsa_code  county_fips5      place_id            yr     index_nsa  \
# count  21965.000000  21965.000000  21965.000000  21965.000000  21965.000000
# mean   29639.869338  30634.770271  29639.869338   2010.000455    180.683128
# std    11273.037179  15623.894785  11273.037179      6.055200     44.176007
# min    10180.000000   1001.000000  10180.000000   2000.000000     87.475000
# 25%    19430.000000  18091.000000  19430.000000   2005.000000    150.752500
# 50%    29200.000000  29177.000000  29200.000000   2010.000000    172.388333
# 75%    39740.000000  46093.000000  39740.000000   2015.000000    200.592500
# max    49740.000000  56025.000000  49740.000000   2020.000000    474.871667
#
#          index_prev    hpi_change       hpi_yoy
# count  21965.000000  21965.000000  21965.000000
# mean     175.049745      5.633383      3.284520
# std       41.829882     10.208160      5.135927
# min       86.007500   -106.320000    -38.965394
# 25%      146.240000      1.336667      0.821768
# 50%      168.522500      5.457500      3.522596
# 75%      194.515000      9.621667      5.686252
# max      446.488333     79.312500     34.789236

# %% [markdown]
# #### Checking for missing counties

# %%
# hpi_county[hpi_county["cbsa_code"] == "10100"]
flood_county[flood_county["FIPS"] == "46045"]
# Out:
# Empty DataFrame
# Columns: [FIPS, YEAR, STATE, CZ_NAME, COUNT, TOTAL_DAMAGE_PROPERTY, TOTAL_DURATION_HOURS]
# Index: []

# %%
min(hpi_county["county_fips5"]), max(hpi_county["county_fips5"])
# Out:
# (1001, 56025)

# %%
mask = ~hpi_county["county_fips5"].isin(flood_county["FIPS"])
hpi_no_flood = hpi_county.loc[mask, "county_fips5"].unique()
hpi_no_flood
# Out:
# array([ 2170, 41031,  9120,  9190,  2090,  9110,  9130, 15005,  9170,
#         9180, 53059, 13173,  9140])

# %%
mask = ~flood_county["FIPS"].isin(hpi_county["county_fips5"])
flood_no_hpi = flood_county.loc[mask, "FIPS"].unique()
flood_no_hpi
# Out:
# array([ 1005,  1011,  1013, ..., 56041, 56043, 56045])

# %% [markdown]
# #### Merge flood and HPI datasets

# %%
hpi_flood = pd.merge(
    hpi_county[["county_fips5", "yr", "hpi_yoy", "index_nsa"]],
    flood_county,
    left_on=["county_fips5", "yr"],
    right_on=["FIPS", "YEAR"],
    how="left",
)

# Identify columns that came from flood_county (excluding join keys)
flood_cols = [c for c in flood_county.columns if c not in ["FIPS", "YEAR"]]

# Impute those flood variables as 0
hpi_flood[flood_cols] = hpi_flood[flood_cols].fillna(0)

# Drop join-key duplicates from the merged df
hpi_flood = hpi_flood.drop(columns=["FIPS", "YEAR"])

hpi_flood.head()
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa  STATE   CZ_NAME  COUNT  \
# 0         48059  2000  1.226954   115.7100      0         0    0.0
# 1         48059  2001  4.070521   120.4200      0         0    0.0
# 2         48059  2002  2.850440   123.8525  TEXAS  CALLAHAN    2.0
# 3         48059  2003  2.620052   127.0975  TEXAS  CALLAHAN    2.0
# 4         48059  2004  4.455241   132.7600  TEXAS  CALLAHAN    4.0
#
#    TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS
# 0                    0.0                  0.00
# 1                    0.0                  0.00
# 2               807000.0                 14.08
# 3                    0.0                  2.00
# 4               100000.0                  4.18

# %%
import numpy as np
hpi_flood = hpi_flood.sort_values(["county_fips5", "yr"])

for col in ["STATE", "CZ_NAME"]:
    hpi_flood[col] = hpi_flood[col].replace([0, "0", "0.0"], np.nan)

# 3. Within each county_fips5, copy non-missing values to all years
hpi_flood[["STATE", "CZ_NAME"]] = (
    hpi_flood
    .groupby("county_fips5")[["STATE", "CZ_NAME"]]
    .ffill()   # fill forward in time
    .bfill()   # fill backward in time (for early years like 2000–2001)
)

# quick check for your example county
hpi_flood.query("county_fips5 == 48059").head(10)
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa  STATE   CZ_NAME  COUNT  \
# 0         48059  2000  1.226954   115.7100  TEXAS  CALLAHAN    0.0
# 1         48059  2001  4.070521   120.4200  TEXAS  CALLAHAN    0.0
# 2         48059  2002  2.850440   123.8525  TEXAS  CALLAHAN    2.0
# 3         48059  2003  2.620052   127.0975  TEXAS  CALLAHAN    2.0
# 4         48059  2004  4.455241   132.7600  TEXAS  CALLAHAN    4.0
# 5         48059  2005  6.922266   141.9500  TEXAS  CALLAHAN    2.0
# 6         48059  2006  8.450159   153.9450  TEXAS  CALLAHAN    0.0
# 7         48059  2007  6.076846   163.3000  TEXAS  CALLAHAN    6.0
# 8         48059  2008  1.987140   166.5450  TEXAS  CALLAHAN    0.0
# 9         48059  2009  2.176589   170.1700  TEXAS  CALLAHAN    0.0
#
#    TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS
# 0                    0.0                  0.00
# 1                    0.0                  0.00
# 2               807000.0                 14.08
# 3                    0.0                  2.00
# 4               100000.0                  4.18
# 5                50000.0                  4.02
# 6                    0.0                  0.00
# 7                 2000.0                 13.20
# 8                    0.0                  0.00
# 9                    0.0                  0.00

# %%
hpi_flood
# Out:
#        county_fips5    yr   hpi_yoy  index_nsa    STATE  CZ_NAME  COUNT  \
# 13755          1001  2000  0.828681   114.6775  ALABAMA  AUTAUGA    1.0
# 13756          1001  2001  4.575876   119.9250  ALABAMA  AUTAUGA    2.0
# 13757          1001  2002  1.736502   122.0075  ALABAMA  AUTAUGA    0.0
# 13758          1001  2003  3.124808   125.8200  ALABAMA  AUTAUGA    2.0
# 13759          1001  2004  2.956605   129.5400  ALABAMA  AUTAUGA    1.0
# ...             ...   ...       ...        ...      ...      ...    ...
# 3124          56025  2016 -1.775084   273.0800  WYOMING  NATRONA    0.0
# 3125          56025  2017 -1.245972   269.6775  WYOMING  NATRONA    1.0
# 3126          56025  2018  1.287649   273.1500  WYOMING  NATRONA    1.0
# 3127          56025  2019  2.738422   280.6300  WYOMING  NATRONA    0.0
# 3128          56025  2020  5.684531   296.5825  WYOMING  NATRONA    0.0
#
#        TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS
# 13755               200000.0                  3.50
# 13756                37000.0                  4.25
# 13757                    0.0                  0.00
# 13758                58000.0                  6.00
# 13759                 8000.0                  3.50
# ...                      ...                   ...
# 3124                     0.0                  0.00
# 3125                     0.0                  1.00
# 3126                     0.0                  1.17
# 3127                     0.0                  0.00
# 3128                     0.0                  0.00
#
# [21965 rows x 9 columns]

# %%
flood_cols
# Out:
# ['STATE', 'CZ_NAME', 'COUNT', 'TOTAL_DAMAGE_PROPERTY', 'TOTAL_DURATION_HOURS']

# %%
# CHECKING FOR DUPLICATES
temp = (
    hpi_flood.value_counts(subset=["county_fips5", "yr"])
    .reset_index()
    .sort_values(by=["county_fips5", "yr"])
)
temp[temp["count"] > 1]
# Out:
# Empty DataFrame
# Columns: [county_fips5, yr, count]
# Index: []

# %% [markdown]
# #### Get heat dataset

# %%
heat_county = pd.read_csv(
    "../../02_processed_data/county_heat_index_2000_2020_with_HSI.csv"
).reset_index(drop=True)
heat_county
# Out:
#            id            name    state  year  value   rank  mean_1901_2000  \
# 0      AL-001  Autauga County  Alabama  2000   93.8  125.0            90.9
# 1      AL-001  Autauga County  Alabama  2001   88.9   18.0            90.9
# 2      AL-001  Autauga County  Alabama  2002   90.8   60.0            90.9
# 3      AL-001  Autauga County  Alabama  2003   88.0    3.0            90.9
# 4      AL-001  Autauga County  Alabama  2004   88.3   11.0            90.9
# ...       ...             ...      ...   ...    ...    ...             ...
# 65242  MD-037       St. Mary&      NaN  2016    NaN    NaN             NaN
# 65243  MD-037       St. Mary&      NaN  2017    NaN    NaN             NaN
# 65244  MD-037       St. Mary&      NaN  2018    NaN    NaN             NaN
# 65245  MD-037       St. Mary&      NaN  2019    NaN    NaN             NaN
# 65246  MD-037       St. Mary&      NaN  2020    NaN    NaN             NaN
#
#        heat_index   rel_dev  abs_z_year  abs_pct_year  exceed_90  exceed_95  \
# 0        0.400821  0.031903    1.316932      0.906059        3.8        0.0
# 1        0.041761 -0.022002    0.622524      0.720271        0.0        0.0
# 2        0.182546 -0.001100    0.838350      0.815985        0.8        0.0
# 3       -0.009982 -0.031903    0.611812      0.704963        0.0        0.0
# 4        0.016426 -0.028603    1.005642      0.811312        0.0        0.0
# ...           ...       ...         ...           ...        ...        ...
# 65242         NaN       NaN         NaN           NaN        NaN        NaN
# 65243         NaN       NaN         NaN           NaN        NaN        NaN
# 65244         NaN       NaN         NaN           NaN        NaN        NaN
# 65245         NaN       NaN         NaN           NaN        NaN        NaN
# 65246         NaN       NaN         NaN           NaN        NaN        NaN
#
#        exceed_100       HSI
# 0             0.0  0.546615
# 1             0.0  0.295779
# 2             0.0  0.378973
# 3             0.0  0.277611
# 4             0.0  0.411246
# ...           ...       ...
# 65242         NaN       NaN
# 65243         NaN       NaN
# 65244         NaN       NaN
# 65245         NaN       NaN
# 65246         NaN       NaN
#
# [65247 rows x 15 columns]

# %%
#### Get the fIPS codes for states

# %%
us_states_fips = pd.read_csv("../../01_original_data/us_states_fips.csv").reset_index(
    drop=True
)
us_states_fips.head()
# Out:
#   state  fips    longname
# 0    AL     1     Alabama
# 1    AK     2      Alaska
# 2    AZ     4     Arizona
# 3    AR     5    Arkansas
# 4    CA     6  California

# %% [markdown]
# #### Create FIPS codes in heat dataset

# %%
def process_fips(heat_county):
    county_split = str(heat_county).split("-")
    state = str(
        us_states_fips[us_states_fips["state"] == county_split[0]]["fips"].values[0]
    ).zfill(2)
    county = county_split[1]
    return state + county


heat_county["FIPS"] = heat_county["id"].apply(lambda x: process_fips(x))
heat_county["FIPS"] = heat_county["FIPS"].astype(int)
heat_county
# Out:
#            id            name    state  year  value   rank  mean_1901_2000  \
# 0      AL-001  Autauga County  Alabama  2000   93.8  125.0            90.9
# 1      AL-001  Autauga County  Alabama  2001   88.9   18.0            90.9
# 2      AL-001  Autauga County  Alabama  2002   90.8   60.0            90.9
# 3      AL-001  Autauga County  Alabama  2003   88.0    3.0            90.9
# 4      AL-001  Autauga County  Alabama  2004   88.3   11.0            90.9
# ...       ...             ...      ...   ...    ...    ...             ...
# 65242  MD-037       St. Mary&      NaN  2016    NaN    NaN             NaN
# 65243  MD-037       St. Mary&      NaN  2017    NaN    NaN             NaN
# 65244  MD-037       St. Mary&      NaN  2018    NaN    NaN             NaN
# 65245  MD-037       St. Mary&      NaN  2019    NaN    NaN             NaN
# 65246  MD-037       St. Mary&      NaN  2020    NaN    NaN             NaN
#
#        heat_index   rel_dev  abs_z_year  abs_pct_year  exceed_90  exceed_95  \
# 0        0.400821  0.031903    1.316932      0.906059        3.8        0.0
# 1        0.041761 -0.022002    0.622524      0.720271        0.0        0.0
# 2        0.182546 -0.001100    0.838350      0.815985        0.8        0.0
# 3       -0.009982 -0.031903    0.611812      0.704963        0.0        0.0
# 4        0.016426 -0.028603    1.005642      0.811312        0.0        0.0
# ...           ...       ...         ...           ...        ...        ...
# 65242         NaN       NaN         NaN           NaN        NaN        NaN
# 65243         NaN       NaN         NaN           NaN        NaN        NaN
# 65244         NaN       NaN         NaN           NaN        NaN        NaN
# 65245         NaN       NaN         NaN           NaN        NaN        NaN
# 65246         NaN       NaN         NaN           NaN        NaN        NaN
#
#        exceed_100       HSI   FIPS
# 0             0.0  0.546615   1001
# 1             0.0  0.295779   1001
# 2             0.0  0.378973   1001
# 3             0.0  0.277611   1001
# 4             0.0  0.411246   1001
# ...           ...       ...    ...
# 65242         NaN       NaN  24037
# 65243         NaN       NaN  24037
# 65244         NaN       NaN  24037
# 65245         NaN       NaN  24037
# 65246         NaN       NaN  24037
#
# [65247 rows x 16 columns]

# %%
# CHECKING FOR DUPLICATES
temp = (
    heat_county.value_counts(subset=["FIPS", "year"])
    .reset_index()
    .sort_values(by=["FIPS", "year"])
)
temp[temp["count"] > 1]
# Out:
# Empty DataFrame
# Columns: [FIPS, year, count]
# Index: []

# %% [markdown]
# #### Merge heat and HPI/flood datasets

# %%
hpi_flood_heat = pd.merge(
    hpi_flood,
    heat_county[["FIPS", "year", "value", "heat_index", "HSI"]],
    left_on=["county_fips5", "yr"],
    right_on=["FIPS", "year"],
    how="left",
)

# Identify columns that came from heat_county, excluding join keys
heat_cols = ["FIPS", "year", "value", "heat_index", "HSI"]

# Impute only heat-related variables as 0
hpi_flood_heat[heat_cols] = hpi_flood_heat[heat_cols].fillna(0)

# Drop join-key duplicates
hpi_flood_heat = hpi_flood_heat.drop(columns=["FIPS", "year"])

hpi_flood_heat.head()
hpi_flood_heat
# Out:
#        county_fips5    yr   hpi_yoy  index_nsa    STATE  CZ_NAME  COUNT  \
# 0              1001  2000  0.828681   114.6775  ALABAMA  AUTAUGA    1.0
# 1              1001  2001  4.575876   119.9250  ALABAMA  AUTAUGA    2.0
# 2              1001  2002  1.736502   122.0075  ALABAMA  AUTAUGA    0.0
# 3              1001  2003  3.124808   125.8200  ALABAMA  AUTAUGA    2.0
# 4              1001  2004  2.956605   129.5400  ALABAMA  AUTAUGA    1.0
# ...             ...   ...       ...        ...      ...      ...    ...
# 21960         56025  2016 -1.775084   273.0800  WYOMING  NATRONA    0.0
# 21961         56025  2017 -1.245972   269.6775  WYOMING  NATRONA    1.0
# 21962         56025  2018  1.287649   273.1500  WYOMING  NATRONA    1.0
# 21963         56025  2019  2.738422   280.6300  WYOMING  NATRONA    0.0
# 21964         56025  2020  5.684531   296.5825  WYOMING  NATRONA    0.0
#
#        TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS  value  heat_index  \
# 0                   200000.0                  3.50   93.8    0.400821
# 1                    37000.0                  4.25   88.9    0.041761
# 2                        0.0                  0.00   90.8    0.182546
# 3                    58000.0                  6.00   88.0   -0.009982
# 4                     8000.0                  3.50   88.3    0.016426
# ...                      ...                   ...    ...         ...
# 21960                    0.0                  0.00   83.4    0.395055
# 21961                    0.0                  1.00   81.6    0.314312
# 21962                    0.0                  1.17   81.7    0.318119
# 21963                    0.0                  0.00   80.4    0.204503
# 21964                    0.0                  0.00   83.7    0.406477
#
#             HSI
# 0      0.546615
# 1      0.295779
# 2      0.378973
# 3      0.277611
# 4      0.411246
# ...         ...
# 21960  0.361178
# 21961  0.283693
# 21962  0.225988
# 21963  0.278252
# 21964  0.334239
#
# [21965 rows x 12 columns]

# %%
temp = (
    hpi_flood_heat.value_counts(subset=["county_fips5", "yr"])
    .reset_index()
    .sort_values(by=["county_fips5", "yr"])
)
temp[temp["count"] > 1]
# Out:
# Empty DataFrame
# Columns: [county_fips5, yr, count]
# Index: []

# %% [markdown]
# #### Merge the drought and wildfire datasets

# %%
drought_county = pd.read_csv(
    "../../02_processed_data/NCEI_annual_drought_county_FINAL.csv"
).reset_index(drop=True)
drought_county = drought_county[drought_county["FIPS"] != 0]
drought_county.sort_values(by=["FIPS", "Year"]).dropna()
drought_county = drought_county.drop(["County", "State", "State_abbr"], axis=1)

# %%
dupes = drought_county[drought_county.duplicated(subset=["FIPS", "Year"], keep=False)]
dupes = dupes.sort_values(by=["FIPS", "Year"])
drought_county = drought_county.drop_duplicates(subset=["FIPS", "Year"], keep="first")
drought_county.head()
# Out:
#    FIPS  Year  Annual_Mean_Index
# 0  1001  2000              -2.32
# 1  1001  2001               1.43
# 2  1001  2002              -0.76
# 3  1001  2003               2.39
# 4  1001  2004               0.00

# %%
drought_hpi_flood_heat = pd.merge(
    hpi_flood_heat,
    drought_county[["FIPS", "Year", "Annual_Mean_Index"]],
    left_on=["county_fips5", "yr"],
    right_on=["FIPS", "Year"],
    how="left",
)

drought_hpi_flood_heat = drought_hpi_flood_heat.drop(columns=["FIPS", "Year"])

drought_hpi_flood_heat["Annual_Mean_Index"] = drought_hpi_flood_heat[
    "Annual_Mean_Index"
].fillna(0)

drought_hpi_flood_heat.head()
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa    STATE  CZ_NAME  COUNT  \
# 0          1001  2000  0.828681   114.6775  ALABAMA  AUTAUGA    1.0
# 1          1001  2001  4.575876   119.9250  ALABAMA  AUTAUGA    2.0
# 2          1001  2002  1.736502   122.0075  ALABAMA  AUTAUGA    0.0
# 3          1001  2003  3.124808   125.8200  ALABAMA  AUTAUGA    2.0
# 4          1001  2004  2.956605   129.5400  ALABAMA  AUTAUGA    1.0
#
#    TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS  value  heat_index       HSI  \
# 0               200000.0                  3.50   93.8    0.400821  0.546615
# 1                37000.0                  4.25   88.9    0.041761  0.295779
# 2                    0.0                  0.00   90.8    0.182546  0.378973
# 3                58000.0                  6.00   88.0   -0.009982  0.277611
# 4                 8000.0                  3.50   88.3    0.016426  0.411246
#
#    Annual_Mean_Index
# 0              -2.32
# 1               1.43
# 2              -0.76
# 3               2.39
# 4               0.00

# %%
# CHECKING FOR DUPLICATES
temp = (
    drought_hpi_flood_heat.value_counts(subset=["county_fips5", "yr"])
    .reset_index()
    .sort_values(by=["county_fips5", "yr"])
)
temp[temp["count"] > 1]
# Out:
# Empty DataFrame
# Columns: [county_fips5, yr, count]
# Index: []

# %%
wildfire_county = pd.read_csv(
    "../../02_processed_data/wildfire_data_preprocessed.csv"
).reset_index(drop=True)
wildfire_county.sort_values(by=["FIPS", "Year"]).dropna()
wildfire_county = wildfire_county.drop(["State"], axis=1)
wildfire_county.head()
# Out:
#    FIPS  Year  FIRE_FREQUENCY  TOTAL_FIRE_SIZE
# 0  1001  2003              43            274.8
# 1  1001  2004              86            744.5
# 2  1001  2005              63            234.2
# 3  1001  2006              62            534.7
# 4  1001  2007              93            477.3

# %%
wildfire_drought_hpi_flood_heat = pd.merge(
    drought_hpi_flood_heat,
    wildfire_county[["FIPS", "Year", "FIRE_FREQUENCY", "TOTAL_FIRE_SIZE"]],
    left_on=["county_fips5", "yr"],
    right_on=["FIPS", "Year"],
    how="left",
)

wildfire_drought_hpi_flood_heat = wildfire_drought_hpi_flood_heat.drop(
    columns=["FIPS", "Year"]
)

wildfire_drought_hpi_flood_heat["FIRE_FREQUENCY"] = wildfire_drought_hpi_flood_heat[
    "FIRE_FREQUENCY"
].fillna(0)
wildfire_drought_hpi_flood_heat["TOTAL_FIRE_SIZE"] = wildfire_drought_hpi_flood_heat[
    "TOTAL_FIRE_SIZE"
].fillna(0)

wildfire_drought_hpi_flood_heat.head()
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa    STATE  CZ_NAME  COUNT  \
# 0          1001  2000  0.828681   114.6775  ALABAMA  AUTAUGA    1.0
# 1          1001  2001  4.575876   119.9250  ALABAMA  AUTAUGA    2.0
# 2          1001  2002  1.736502   122.0075  ALABAMA  AUTAUGA    0.0
# 3          1001  2003  3.124808   125.8200  ALABAMA  AUTAUGA    2.0
# 4          1001  2004  2.956605   129.5400  ALABAMA  AUTAUGA    1.0
#
#    TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS  value  heat_index       HSI  \
# 0               200000.0                  3.50   93.8    0.400821  0.546615
# 1                37000.0                  4.25   88.9    0.041761  0.295779
# 2                    0.0                  0.00   90.8    0.182546  0.378973
# 3                58000.0                  6.00   88.0   -0.009982  0.277611
# 4                 8000.0                  3.50   88.3    0.016426  0.411246
#
#    Annual_Mean_Index  FIRE_FREQUENCY  TOTAL_FIRE_SIZE
# 0              -2.32             0.0              0.0
# 1               1.43             0.0              0.0
# 2              -0.76             0.0              0.0
# 3               2.39            43.0            274.8
# 4               0.00            86.0            744.5

# %%
# CHECKING FOR DUPLICATES
temp = (
    wildfire_drought_hpi_flood_heat.value_counts(subset=["county_fips5", "yr"])
    .reset_index()
    .sort_values(by=["county_fips5", "yr"])
)
temp[temp["count"] > 1]
# Out:
# Empty DataFrame
# Columns: [county_fips5, yr, count]
# Index: []

# %% [markdown]
# #### Merge Drought/Wildfire/HPI/Flood/Heat/Hurricane datasets

# %%
storm_summary = pd.read_csv(
    "../../02_processed_data/storm_data_aggregated_county.csv", low_memory=False
)
storm_summary["year"] = storm_summary["year"].astype("int")
storm_summary["FIPS"] = storm_summary["FIPS"].astype("int")

huricane_grouped = storm_summary.groupby(["FIPS", "year"], as_index=False).agg(
    deaths_hurricane=("deaths", "sum"),
    injuries_hurricane=("injuries", "sum"),
    damage_hurricane=("damage", "sum"),
)

huricane_grouped.sort_values(by=["FIPS", "year"])
# Out:
#       FIPS  year  deaths_hurricane  injuries_hurricane  damage_hurricane
# 0     1003  2002               0.0                 0.0             75000
# 1     1003  2004               0.0                 0.0                 0
# 2     1003  2005               0.0                 0.0                 0
# 3     1003  2020               2.0                 0.0         236080000
# 4     1013  2004               0.0                 0.0                 0
# ..     ...   ...               ...                 ...               ...
# 947  51730  2003               1.0                 0.0           9700000
# 948  51740  2003               0.0                 0.0          10000000
# 949  51800  2003               0.0                 0.0          33000000
# 950  51810  2003               0.0                 0.0          39400000
# 951  51830  2003               0.0                 0.0          45046000
#
# [952 rows x 5 columns]

# %%
wildfire_drought_hpi_flood_heat_huricane = pd.merge(
    wildfire_drought_hpi_flood_heat,
    huricane_grouped,
    left_on=["county_fips5", "yr"],
    right_on=["FIPS", "year"],
    how="left",
)

# Columns coming from huricane_grouped, excluding join keys
hurricane_cols = [c for c in huricane_grouped.columns if c not in ["FIPS", "year"]]

# Impute only hurricane variables as 0
wildfire_drought_hpi_flood_heat_huricane[hurricane_cols] = (
    wildfire_drought_hpi_flood_heat_huricane[hurricane_cols].fillna(0)
)


wildfire_drought_hpi_flood_heat_huricane
# Out:
#        county_fips5    yr   hpi_yoy  index_nsa    STATE  CZ_NAME  COUNT  \
# 0              1001  2000  0.828681   114.6775  ALABAMA  AUTAUGA    1.0
# 1              1001  2001  4.575876   119.9250  ALABAMA  AUTAUGA    2.0
# 2              1001  2002  1.736502   122.0075  ALABAMA  AUTAUGA    0.0
# 3              1001  2003  3.124808   125.8200  ALABAMA  AUTAUGA    2.0
# 4              1001  2004  2.956605   129.5400  ALABAMA  AUTAUGA    1.0
# ...             ...   ...       ...        ...      ...      ...    ...
# 21960         56025  2016 -1.775084   273.0800  WYOMING  NATRONA    0.0
# 21961         56025  2017 -1.245972   269.6775  WYOMING  NATRONA    1.0
# 21962         56025  2018  1.287649   273.1500  WYOMING  NATRONA    1.0
# 21963         56025  2019  2.738422   280.6300  WYOMING  NATRONA    0.0
# 21964         56025  2020  5.684531   296.5825  WYOMING  NATRONA    0.0
#
#        TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS  value  heat_index  \
# 0                   200000.0                  3.50   93.8    0.400821
# 1                    37000.0                  4.25   88.9    0.041761
# 2                        0.0                  0.00   90.8    0.182546
# 3                    58000.0                  6.00   88.0   -0.009982
# 4                     8000.0                  3.50   88.3    0.016426
# ...                      ...                   ...    ...         ...
# 21960                    0.0                  0.00   83.4    0.395055
# 21961                    0.0                  1.00   81.6    0.314312
# 21962                    0.0                  1.17   81.7    0.318119
# 21963                    0.0                  0.00   80.4    0.204503
# 21964                    0.0                  0.00   83.7    0.406477
#
#             HSI  Annual_Mean_Index  FIRE_FREQUENCY  TOTAL_FIRE_SIZE  FIPS  \
# 0      0.546615              -2.32             0.0            0.000   NaN
# 1      0.295779               1.43             0.0            0.000   NaN
# 2      0.378973              -0.76             0.0            0.000   NaN
# 3      0.277611               2.39            43.0          274.800   NaN
# 4      0.411246               0.00            86.0          744.500   NaN
# ...         ...                ...             ...              ...   ...
# 21960  0.361178              -0.03            40.0          897.000   NaN
# 21961  0.283693              -0.64            46.0         3586.400   NaN
# 21962  0.225988              -1.63            73.0         1422.100   NaN
# 21963  0.278252               1.87            60.0          406.600   NaN
# 21964  0.334239              -1.45           156.0         3591.457   NaN
#
#        year  deaths_hurricane  injuries_hurricane  damage_hurricane
# 0       NaN               0.0                 0.0               0.0
# 1       NaN               0.0                 0.0               0.0
# 2       NaN               0.0                 0.0               0.0
# 3       NaN               0.0                 0.0               0.0
# 4       NaN               0.0                 0.0               0.0
# ...     ...               ...                 ...               ...
# 21960   NaN               0.0                 0.0               0.0
# 21961   NaN               0.0                 0.0               0.0
# 21962   NaN               0.0                 0.0               0.0
# 21963   NaN               0.0                 0.0               0.0
# 21964   NaN               0.0                 0.0               0.0
#
# [21965 rows x 20 columns]

# %%
climate = wildfire_drought_hpi_flood_heat_huricane

# columns to drop
cols_to_drop = ["YEAR", "year_y", "State_fire", "State_ncei", "State_abbr", "Year", "year_x", "FIPS", "year", "value", "heat_index", "CZ_NAME"]

# drop them from df (ignore any that might be missing)
climate = climate.drop(columns=cols_to_drop, errors="ignore")

# quick check
print(climate.columns)
print(climate.info())
print(climate.describe())
# Out:
# Index(['county_fips5', 'yr', 'hpi_yoy', 'index_nsa', 'STATE', 'COUNT',
#        'TOTAL_DAMAGE_PROPERTY', 'TOTAL_DURATION_HOURS', 'HSI',
#        'Annual_Mean_Index', 'FIRE_FREQUENCY', 'TOTAL_FIRE_SIZE',
#        'deaths_hurricane', 'injuries_hurricane', 'damage_hurricane'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21965 entries, 0 to 21964
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county_fips5           21965 non-null  int64
#  1   yr                     21965 non-null  int64
#  2   hpi_yoy                21965 non-null  float64
#  3   index_nsa              21965 non-null  float64
#  4   STATE                  21965 non-null  object
#  5   COUNT                  21965 non-null  float64
#  6   TOTAL_DAMAGE_PROPERTY  21965 non-null  float64
#  7   TOTAL_DURATION_HOURS   21965 non-null  float64
#  8   HSI                    21965 non-null  float64
#  9   Annual_Mean_Index      21965 non-null  float64
#  10  FIRE_FREQUENCY         21965 non-null  float64
#  11  TOTAL_FIRE_SIZE        21965 non-null  float64
#  12  deaths_hurricane       21965 non-null  float64
#  13  injuries_hurricane     21965 non-null  float64
#  14  damage_hurricane       21965 non-null  float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 2.5+ MB
# None
#        county_fips5            yr       hpi_yoy     index_nsa         COUNT  \
# count  21965.000000  21965.000000  21965.000000  21965.000000  21965.000000
# mean   30634.770271   2010.000455      3.284520    180.683128      8.074118
# std    15623.894785      6.055200      5.135927     44.176007     16.121942
# min     1001.000000   2000.000000    -38.965394     87.475000      0.000000
# 25%    18091.000000   2005.000000      0.821768    150.752500      0.000000
# 50%    29177.000000   2010.000000      3.522596    172.388333      1.000000
# 75%    46093.000000   2015.000000      5.686252    200.592500      8.000000
# max    56025.000000   2020.000000     34.789236    474.871667    194.000000
#
#        TOTAL_DAMAGE_PROPERTY  TOTAL_DURATION_HOURS           HSI  \
# count           2.196500e+04          21965.000000  21965.000000
# mean            3.587691e+06             59.048402      0.323221
# std             1.271277e+08            334.408495      0.131547
# min             0.000000e+00              0.000000      0.000000
# 25%             0.000000e+00              0.000000      0.230169
# 50%             0.000000e+00              2.000000      0.316636
# 75%             1.000000e+04             13.670000      0.413298
# max             1.000051e+10          18464.230000      0.958256
#
#        Annual_Mean_Index  FIRE_FREQUENCY  TOTAL_FIRE_SIZE  deaths_hurricane  \
# count       21965.000000    21965.000000     21965.000000      21965.000000
# mean            0.235479       27.170225      1334.046593          0.050899
# std             2.014463       74.185753     12027.213120          4.481132
# min            -7.590000        0.000000         0.000000          0.000000
# 25%            -1.010000        0.000000         0.000000          0.000000
# 50%             0.110000        5.000000        14.000000          0.000000
# 75%             1.550000       28.000000       159.000000          0.000000
# max             8.680000     4696.000000    511931.900000        638.000000
#
#        injuries_hurricane  damage_hurricane
# count        21965.000000      2.196500e+04
# mean             0.151377      3.854190e+06
# std             16.878547      1.007831e+08
# min              0.000000      0.000000e+00
# 25%              0.000000      0.000000e+00
# 50%              0.000000      0.000000e+00
# 75%              0.000000      0.000000e+00
# max           2400.000000      7.000000e+09

# %%
climate = climate.rename(
    columns={
        "COUNT": "FLOOD_FREQUENCY",
        "TOTAL_DAMAGE_PROPERTY": "FLOOD_PROPERTY_DAMAGE",
        "TOTAL_DURATION_HOURS": "FLOOD_DURATION_HOURS",
        "HSI": "HEAT_STRESS_INDEX",
        "Annual_Mean_Index": "DROUGHT_ANNUAL_MEAN_INDEX",
        "TOTAL_FIRE_SIZE": "FIRE_SIZE",
    }
)
climate.columns
# Out:
# Index(['county_fips5', 'yr', 'hpi_yoy', 'index_nsa', 'STATE',
#        'FLOOD_FREQUENCY', 'FLOOD_PROPERTY_DAMAGE', 'FLOOD_DURATION_HOURS',
#        'HEAT_STRESS_INDEX', 'DROUGHT_ANNUAL_MEAN_INDEX', 'FIRE_FREQUENCY',
#        'FIRE_SIZE', 'deaths_hurricane', 'injuries_hurricane',
#        'damage_hurricane'],
#       dtype='object')

# %%
gdp = pd.read_csv("../../01_original_data/Financial Data/GDP_cleaned.csv")
gdp_small = gdp[["GeoFIPS", "Year", "Real_GDP"]]

# %%
years_per_county = (
    gdp_small
    .groupby("GeoFIPS")["Year"]
    .nunique()
    .reset_index(name="n_years")
    .sort_values("n_years")
)
years_per_county.head()
# Out:
#       GeoFIPS  n_years
# 0        1001       23
# 2111    39059       23
# 2112    39061       23
# 2113    39063       23
# 2114    39065       23

# %%
counties_per_year = (
    gdp_small
    .groupby("Year")["GeoFIPS"]
    .nunique()
    .reset_index(name="n_counties")
    .sort_values("Year")
)
counties_per_year
# Out:
#     Year  n_counties
# 0   2001        3176
# 1   2002        3176
# 2   2003        3176
# 3   2004        3176
# 4   2005        3176
# 5   2006        3176
# 6   2007        3176
# 7   2008        3176
# 8   2009        3176
# 9   2010        3176
# 10  2011        3176
# 11  2012        3176
# 12  2013        3176
# 13  2014        3176
# 14  2015        3176
# 15  2016        3176
# 16  2017        3176
# 17  2018        3176
# 18  2019        3176
# 19  2020        3176
# 20  2021        3176
# 21  2022        3176
# 22  2023        3176

# %% [markdown]
# # dropping 2000 year data is ideal here as 2000 year data is completely missing here.

# %%
climate_gdp = pd.merge(
    climate,
    gdp_small,
    left_on=["county_fips5", "yr"],
    right_on=["GeoFIPS", "Year"],
    how="left",
)
climate_gdp = climate_gdp.drop(columns=["GeoFIPS", "Year"])
climate_gdp.head()
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa    STATE  FLOOD_FREQUENCY  \
# 0          1001  2000  0.828681   114.6775  ALABAMA              1.0
# 1          1001  2001  4.575876   119.9250  ALABAMA              2.0
# 2          1001  2002  1.736502   122.0075  ALABAMA              0.0
# 3          1001  2003  3.124808   125.8200  ALABAMA              2.0
# 4          1001  2004  2.956605   129.5400  ALABAMA              1.0
#
#    FLOOD_PROPERTY_DAMAGE  FLOOD_DURATION_HOURS  HEAT_STRESS_INDEX  \
# 0               200000.0                  3.50           0.546615
# 1                37000.0                  4.25           0.295779
# 2                    0.0                  0.00           0.378973
# 3                58000.0                  6.00           0.277611
# 4                 8000.0                  3.50           0.411246
#
#    DROUGHT_ANNUAL_MEAN_INDEX  FIRE_FREQUENCY  FIRE_SIZE  deaths_hurricane  \
# 0                      -2.32             0.0        0.0               0.0
# 1                       1.43             0.0        0.0               0.0
# 2                      -0.76             0.0        0.0               0.0
# 3                       2.39            43.0      274.8               0.0
# 4                       0.00            86.0      744.5               0.0
#
#    injuries_hurricane  damage_hurricane Real_GDP
# 0                 0.0               0.0      NaN
# 1                 0.0               0.0  1041239
# 2                 0.0               0.0  1080135
# 3                 0.0               0.0  1111465
# 4                 0.0               0.0  1283522

# %%
unemployment = pd.read_csv("../../01_original_data/Financial Data/Unemployment2023_cleaned.csv")
unemployment_small = unemployment[["FIPS_Code", "Year", "Unemployment_Rate"]]

# %%
climate_gdp_unemployment = pd.merge(
    climate_gdp,
    unemployment_small,
    left_on=["county_fips5", "yr"],
    right_on=["FIPS_Code", "Year"],
    how="left",
)
climate_gdp_unemployment = climate_gdp_unemployment.drop(columns=["FIPS_Code", "Year"])
climate_gdp_unemployment.head()
# Out:
#    county_fips5    yr   hpi_yoy  index_nsa    STATE  FLOOD_FREQUENCY  \
# 0          1001  2000  0.828681   114.6775  ALABAMA              1.0
# 1          1001  2001  4.575876   119.9250  ALABAMA              2.0
# 2          1001  2002  1.736502   122.0075  ALABAMA              0.0
# 3          1001  2003  3.124808   125.8200  ALABAMA              2.0
# 4          1001  2004  2.956605   129.5400  ALABAMA              1.0
#
#    FLOOD_PROPERTY_DAMAGE  FLOOD_DURATION_HOURS  HEAT_STRESS_INDEX  \
# 0               200000.0                  3.50           0.546615
# 1                37000.0                  4.25           0.295779
# 2                    0.0                  0.00           0.378973
# 3                58000.0                  6.00           0.277611
# 4                 8000.0                  3.50           0.411246
#
#    DROUGHT_ANNUAL_MEAN_INDEX  FIRE_FREQUENCY  FIRE_SIZE  deaths_hurricane  \
# 0                      -2.32             0.0        0.0               0.0
# 1                       1.43             0.0        0.0               0.0
# 2                      -0.76             0.0        0.0               0.0
# 3                       2.39            43.0      274.8               0.0
# 4                       0.00            86.0      744.5               0.0
#
#    injuries_hurricane  damage_hurricane Real_GDP  Unemployment_Rate
# 0                 0.0               0.0      NaN                4.1
# 1                 0.0               0.0  1041239                4.1
# 2                 0.0               0.0  1080135                4.8
# 3                 0.0               0.0  1111465                5.0
# 4                 0.0               0.0  1283522                4.7

# %%
# rows where unemployment is missing
missing_unemp = (
    climate_gdp_unemployment
    .loc[climate_gdp_unemployment["Unemployment_Rate"].isna(),
         ["county_fips5", "yr"]]
    .drop_duplicates()
    .sort_values(["county_fips5", "yr"])
)

print(missing_unemp)     # nice table of county + year combos

# if you want them in a single "vector" of tuples:
missing_unemp_vec = list(missing_unemp.itertuples(index=False, name=None))
print(missing_unemp_vec)

# or as strings like "county-year"
missing_unemp_str = [f"{c}-{y}" for c, y in missing_unemp_vec]
print(missing_unemp_str)
# Out:
#       county_fips5    yr
# 2226          9110  2000
# 2227          9110  2001
# 2228          9110  2002
# 2229          9110  2003
# 2230          9110  2004
# ...            ...   ...
# 8153         22089  2006
# 8215         22095  2005
# 8216         22095  2006
# 8257         22103  2005
# 8258         22103  2006
#
# [182 rows x 2 columns]
# [(9110, 2000), (9110, 2001), (9110, 2002), (9110, 2003), (9110, 2004), (9110, 2005), (9110, 2006), (9110, 2007), (9110, 2008), (9110, 2009), (9110, 2010), (9110, 2011), (9110, 2012), (9110, 2013), (9110, 2014), (9110, 2015), (9110, 2016), (9110, 2017), (9110, 2018), (9110, 2019), (9110, 2020), (9120, 2000), (9120, 2001), (9120, 2002), (9120, 2003), (9120, 2004), (9120, 2005), (9120, 2006), (9120, 2007), (9120, 2008), (9120, 2009), (9120, 2010), (9120, 2011), (9120, 2012), (9120, 2013), (9120, 2014), (9120, 2015), (9120, 2016), (9120, 2017), (9120, 2018), (9120, 2019), (9120, 2020), (9130, 2000), (9130, 2001), (9130, 2002), (9130, 2003), (9130, 2004), (9130, 2005), (9130, 2006), (9130, 2007), (9130, 2008), (9130, 2009), (9130, 2010), (9130, 2011), (9130, 2012), (9130, 2013), (9130, 2014), (9130, 2015), (9130, 2016), (9130, 2017), (9130, 2018), (9130, 2019), (9130, 2020), (9140, 2000), (9140, 2001), (9140, 2002), (9140, 2003), (9140, 2004), (9140, 2005), (9140, 2006), (9140, 2007), (9140, 2008), (9140, 2009), (9140, 2010), (9140, 2011), (9140, 2012), (9140, 2013), (9140, 2014), (9140, 2015), (9140, 2016), (9140, 2017), (9140, 2018), (9140, 2019), (9140, 2020), (9170, 2000), (9170, 2001), (9170, 2002), (9170, 2003), (9170, 2004), (9170, 2005), (9170, 2006), (9170, 2007), (9170, 2008), (9170, 2009), (9170, 2010), (9170, 2011), (9170, 2012), (9170, 2013), (9170, 2014), (9170, 2015), (9170, 2016), (9170, 2017), (9170, 2018), (9170, 2019), (9170, 2020), (9180, 2000), (9180, 2001), (9180, 2002), (9180, 2003), (9180, 2004), (9180, 2005), (9180, 2006), (9180, 2007), (9180, 2008), (9180, 2009), (9180, 2010), (9180, 2011), (9180, 2012), (9180, 2013), (9180, 2014), (9180, 2015), (9180, 2016), (9180, 2017), (9180, 2018), (9180, 2019), (9180, 2020), (9190, 2000), (9190, 2001), (9190, 2002), (9190, 2003), (9190, 2004), (9190, 2005), (9190, 2006), (9190, 2007), (9190, 2008), (9190, 2009), (9190, 2010), (9190, 2011), (9190, 2012), (9190, 2013), (9190, 2014), (9190, 2015), (9190, 2016), (9190, 2017), (9190, 2018), (9190, 2019), (9190, 2020), (15005, 2000), (15005, 2001), (15005, 2002), (15005, 2003), (15005, 2004), (15005, 2005), (15005, 2006), (15005, 2007), (15005, 2008), (15005, 2009), (15005, 2010), (15005, 2011), (15005, 2012), (15005, 2013), (15005, 2014), (15005, 2015), (15005, 2016), (15005, 2017), (15005, 2018), (15005, 2019), (15005, 2020), (22051, 2005), (22051, 2006), (22071, 2005), (22071, 2006), (22075, 2005), (22075, 2006), (22087, 2005), (22087, 2006), (22089, 2005), (22089, 2006), (22095, 2005), (22095, 2006), (22103, 2005), (22103, 2006)]
# ['9110-2000', '9110-2001', '9110-2002', '9110-2003', '9110-2004', '9110-2005', '9110-2006', '9110-2007', '9110-2008', '9110-2009', '9110-2010', '9110-2011', '9110-2012', '9110-2013', '9110-2014', '9110-2015', '9110-2016', '9110-2017', '9110-2018', '9110-2019', '9110-2020', '9120-2000', '9120-2001', '9120-2002', '9120-2003', '9120-2004', '9120-2005', '9120-2006', '9120-2007', '9120-2008', '9120-2009', '9120-2010', '9120-2011', '9120-2012', '9120-2013', '9120-2014', '9120-2015', '9120-2016', '9120-2017', '9120-2018', '9120-2019', '9120-2020', '9130-2000', '9130-2001', '9130-2002', '9130-2003', '9130-2004', '9130-2005', '9130-2006', '9130-2007', '9130-2008', '9130-2009', '9130-2010', '9130-2011', '9130-2012', '9130-2013', '9130-2014', '9130-2015', '9130-2016', '9130-2017', '9130-2018', '9130-2019', '9130-2020', '9140-2000', '9140-2001', '9140-2002', '9140-2003', '9140-2004', '9140-2005', '9140-2006', '9140-2007', '9140-2008', '9140-2009', '9140-2010', '9140-2011', '9140-2012', '9140-2013', '9140-2014', '9140-2015', '9140-2016', '9140-2017', '9140-2018', '9140-2019', '9140-2020', '9170-2000', '9170-2001', '9170-2002', '9170-2003', '9170-2004', '9170-2005', '9170-2006', '9170-2007', '9170-2008', '9170-2009', '9170-2010', '9170-2011', '9170-2012', '9170-2013', '9170-2014', '9170-2015', '9170-2016', '9170-2017', '9170-2018', '9170-2019', '9170-2020', '9180-2000', '9180-2001', '9180-2002', '9180-2003', '9180-2004', '9180-2005', '9180-2006', '9180-2007', '9180-2008', '9180-2009', '9180-2010', '9180-2011', '9180-2012', '9180-2013', '9180-2014', '9180-2015', '9180-2016', '9180-2017', '9180-2018', '9180-2019', '9180-2020', '9190-2000', '9190-2001', '9190-2002', '9190-2003', '9190-2004', '9190-2005', '9190-2006', '9190-2007', '9190-2008', '9190-2009', '9190-2010', '9190-2011', '9190-2012', '9190-2013', '9190-2014', '9190-2015', '9190-2016', '9190-2017', '9190-2018', '9190-2019', '9190-2020', '15005-2000', '15005-2001', '15005-2002', '15005-2003', '15005-2004', '15005-2005', '15005-2006', '15005-2007', '15005-2008', '15005-2009', '15005-2010', '15005-2011', '15005-2012', '15005-2013', '15005-2014', '15005-2015', '15005-2016', '15005-2017', '15005-2018', '15005-2019', '15005-2020', '22051-2005', '22051-2006', '22071-2005', '22071-2006', '22075-2005', '22075-2006', '22087-2005', '22087-2006', '22089-2005', '22089-2006', '22095-2005', '22095-2006', '22103-2005', '22103-2006']

# %%
df = climate_gdp_unemployment

all_missing_prop = (
    df.groupby("county_fips5")["Unemployment_Rate"]
      .apply(lambda s: s.isna().all())
      .reset_index(name="all_missing_Unemployment_Rate")
)

n_counties_all_Unemployement_Rate = all_missing_prop["all_missing_Unemployment_Rate"].sum()
print("Counties with Unemployment rate missing for ALL years:", n_counties_all_Unemployement_Rate)

# optionally list them
counties_all_missing_prop = all_missing_prop.loc[
    all_missing_prop["all_missing_Unemployment_Rate"], "county_fips5"
].tolist()
print("county_fips5 with Unemployment_Rate missing for all years:", n_counties_all_Unemployement_Rate)
n_counties_all_Unemployement_Rate
# Out:
# Counties with Unemployment rate missing for ALL years: 8
# county_fips5 with Unemployment_Rate missing for all years: 8
# 8

# %%
# total NA count per column
climate_gdp_unemployment.isna().sum().sort_values(ascending=False)

# percentage of NA per column
(climate_gdp_unemployment.isna().mean().sort_values(ascending=False) * 100).round(2)
# Out:
# Real_GDP                     7.94
# Unemployment_Rate            0.83
# HEAT_STRESS_INDEX            0.00
# damage_hurricane             0.00
# injuries_hurricane           0.00
# deaths_hurricane             0.00
# FIRE_SIZE                    0.00
# FIRE_FREQUENCY               0.00
# DROUGHT_ANNUAL_MEAN_INDEX    0.00
# row_id                       0.00
# row_id                       0.00
# FLOOD_PROPERTY_DAMAGE        0.00
# FLOOD_FREQUENCY              0.00
# STATE                        0.00
# index_nsa                    0.00
# hpi_yoy                      0.00
# yr                           0.00
# county_fips5                 0.00
# FLOOD_DURATION_HOURS         0.00
# dtype: float64

# %%
property_tax = pd.read_csv("../../01_original_data/Financial Data/property_tax_cleaned.csv")

# %%
climate_gdp_unemployment_tax = pd.merge(
    climate_gdp_unemployment,
    property_tax,
    left_on=["county_fips5", "yr"],
    right_on=["fips", "year"],
    how="left",
)
climate_gdp_unemployment_tax = climate_gdp_unemployment_tax.drop(columns=["fips", "year"])
climate_gdp_unemployment_tax.head()
# Out:
#    row_id  row_id  county_fips5    yr   hpi_yoy  index_nsa    STATE  \
# 0       0       0          1001  2000  0.828681   114.6775  ALABAMA
# 1       1       1          1001  2001  4.575876   119.9250  ALABAMA
# 2       2       2          1001  2002  1.736502   122.0075  ALABAMA
# 3       3       3          1001  2003  3.124808   125.8200  ALABAMA
# 4       4       4          1001  2004  2.956605   129.5400  ALABAMA
#
#    FLOOD_FREQUENCY  FLOOD_PROPERTY_DAMAGE  FLOOD_DURATION_HOURS  \
# 0              1.0               200000.0                  3.50
# 1              2.0                37000.0                  4.25
# 2              0.0                    0.0                  0.00
# 3              2.0                58000.0                  6.00
# 4              1.0                 8000.0                  3.50
#
#    HEAT_STRESS_INDEX  DROUGHT_ANNUAL_MEAN_INDEX  FIRE_FREQUENCY  FIRE_SIZE  \
# 0           0.546615                      -2.32             0.0        0.0
# 1           0.295779                       1.43             0.0        0.0
# 2           0.378973                      -0.76             0.0        0.0
# 3           0.277611                       2.39            43.0      274.8
# 4           0.411246                       0.00            86.0      744.5
#
#    deaths_hurricane  injuries_hurricane  damage_hurricane Real_GDP  \
# 0               0.0                 0.0               0.0      NaN
# 1               0.0                 0.0               0.0  1041239
# 2               0.0                 0.0               0.0  1080135
# 3               0.0                 0.0               0.0  1111465
# 4               0.0                 0.0               0.0  1283522
#
#    Unemployment_Rate  prop_rate
# 0                4.1        NaN
# 1                4.1        NaN
# 2                4.8        NaN
# 3                5.0      0.245
# 4                4.7      0.245

# %%
population = pd.read_parquet("../../01_original_data/population/Population_Data_2003_2019.parquet")
population_long = population.melt(
    id_vars=["FIPSCODE", "STNAME", "CTYNAME"], 
    value_vars=[col for col in population.columns if col.startswith("POPESTIMATE")],
    var_name="year", 
    value_name="population"
)
population_long["year"] = population_long["year"].str.extract("(\d+)").astype(int)
population_small = population_long[["FIPSCODE", "year", "population"]]
population_small.head()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/26/4y4fzxhd7td390hxfyvrnw1m0000gp/T/ipykernel_27862/4051454054.py:8: SyntaxWarning: invalid escape sequence '\d'
#   population_long["year"] = population_long["year"].str.extract("(\d+)").astype(int)
#   FIPSCODE  year  population
# 0    01000  2003   4503491.0
# 1    01001  2003     46800.0
# 2    01003  2003    151509.0
# 3    01005  2003     28594.0
# 4    01007  2003     21399.0

# %%
# Add zero to 4 digits FIPS Code
climate_gdp_unemployment_tax["county_fips5"] = climate_gdp_unemployment_tax["county_fips5"].astype(str).str.zfill(5)

climate_gdp_unemployment_tax_population = pd.merge(
    climate_gdp_unemployment_tax,
    population_small,
    left_on=["county_fips5", "yr"],
    right_on=["FIPSCODE", "year"],
    how="left",
)
climate_gdp_unemployment_tax_population = climate_gdp_unemployment_tax_population.drop(columns=["FIPSCODE", "year"])
climate_gdp_unemployment_tax_population.head()
# Out:
#    row_id  row_id county_fips5    yr   hpi_yoy  index_nsa    STATE  \
# 0       0       0        01001  2000  0.828681   114.6775  ALABAMA
# 1       1       1        01001  2001  4.575876   119.9250  ALABAMA
# 2       2       2        01001  2002  1.736502   122.0075  ALABAMA
# 3       3       3        01001  2003  3.124808   125.8200  ALABAMA
# 4       4       4        01001  2004  2.956605   129.5400  ALABAMA
#
#    FLOOD_FREQUENCY  FLOOD_PROPERTY_DAMAGE  FLOOD_DURATION_HOURS  ...  \
# 0              1.0               200000.0                  3.50  ...
# 1              2.0                37000.0                  4.25  ...
# 2              0.0                    0.0                  0.00  ...
# 3              2.0                58000.0                  6.00  ...
# 4              1.0                 8000.0                  3.50  ...
#
#    DROUGHT_ANNUAL_MEAN_INDEX  FIRE_FREQUENCY  FIRE_SIZE  deaths_hurricane  \
# 0                      -2.32             0.0        0.0               0.0
# 1                       1.43             0.0        0.0               0.0
# 2                      -0.76             0.0        0.0               0.0
# 3                       2.39            43.0      274.8               0.0
# 4                       0.00            86.0      744.5               0.0
#
#    injuries_hurricane  damage_hurricane  Real_GDP Unemployment_Rate  \
# 0                 0.0               0.0       NaN               4.1
# 1                 0.0               0.0   1041239               4.1
# 2                 0.0               0.0   1080135               4.8
# 3                 0.0               0.0   1111465               5.0
# 4                 0.0               0.0   1283522               4.7
#
#    prop_rate  population
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3      0.245     46800.0
# 4      0.245     48366.0
#
# [5 rows x 21 columns]

# %%
climate_gdp_unemployment_tax_population
# Out:
#        row_id  row_id county_fips5    yr   hpi_yoy  index_nsa    STATE  \
# 0           0       0        01001  2000  0.828681   114.6775  ALABAMA
# 1           1       1        01001  2001  4.575876   119.9250  ALABAMA
# 2           2       2        01001  2002  1.736502   122.0075  ALABAMA
# 3           3       3        01001  2003  3.124808   125.8200  ALABAMA
# 4           4       4        01001  2004  2.956605   129.5400  ALABAMA
# ...       ...     ...          ...   ...       ...        ...      ...
# 21960   21960   21960        56025  2016 -1.775084   273.0800  WYOMING
# 21961   21961   21961        56025  2017 -1.245972   269.6775  WYOMING
# 21962   21962   21962        56025  2018  1.287649   273.1500  WYOMING
# 21963   21963   21963        56025  2019  2.738422   280.6300  WYOMING
# 21964   21964   21964        56025  2020  5.684531   296.5825  WYOMING
#
#        FLOOD_FREQUENCY  FLOOD_PROPERTY_DAMAGE  FLOOD_DURATION_HOURS  ...  \
# 0                  1.0               200000.0                  3.50  ...
# 1                  2.0                37000.0                  4.25  ...
# 2                  0.0                    0.0                  0.00  ...
# 3                  2.0                58000.0                  6.00  ...
# 4                  1.0                 8000.0                  3.50  ...
# ...                ...                    ...                   ...  ...
# 21960              0.0                    0.0                  0.00  ...
# 21961              1.0                    0.0                  1.00  ...
# 21962              1.0                    0.0                  1.17  ...
# 21963              0.0                    0.0                  0.00  ...
# 21964              0.0                    0.0                  0.00  ...
#
#        DROUGHT_ANNUAL_MEAN_INDEX  FIRE_FREQUENCY  FIRE_SIZE  deaths_hurricane  \
# 0                          -2.32             0.0      0.000               0.0
# 1                           1.43             0.0      0.000               0.0
# 2                          -0.76             0.0      0.000               0.0
# 3                           2.39            43.0    274.800               0.0
# 4                           0.00            86.0    744.500               0.0
# ...                          ...             ...        ...               ...
# 21960                      -0.03            40.0    897.000               0.0
# 21961                      -0.64            46.0   3586.400               0.0
# 21962                      -1.63            73.0   1422.100               0.0
# 21963                       1.87            60.0    406.600               0.0
# 21964                      -1.45           156.0   3591.457               0.0
#
#        injuries_hurricane  damage_hurricane  Real_GDP Unemployment_Rate  \
# 0                     0.0               0.0       NaN               4.1
# 1                     0.0               0.0   1041239               4.1
# 2                     0.0               0.0   1080135               4.8
# 3                     0.0               0.0   1111465               5.0
# 4                     0.0               0.0   1283522               4.7
# ...                   ...               ...       ...               ...
# 21960                 0.0               0.0   5663254               7.2
# 21961                 0.0               0.0   5594566               5.4
# 21962                 0.0               0.0   5920361               4.6
# 21963                 0.0               0.0   5705706               4.0
# 21964                 0.0               0.0   4980782               7.9
#
#        prop_rate  population
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3          0.245     46800.0
# 4          0.245     48366.0
# ...          ...         ...
# 21960        NaN     80909.0
# 21961        NaN     79586.0
# 21962        NaN     79175.0
# 21963        NaN     79858.0
# 21964        NaN         NaN
#
# [21965 rows x 21 columns]

# %%
# total NA count per column
climate_gdp_unemployment_tax_population.isna().sum().sort_values(ascending=False)

# percentage of NA per column
(climate_gdp_unemployment_tax_population.isna().mean().sort_values(ascending=False) * 100).round(2)
# Out:
# prop_rate                    39.34
# population                   24.53
# Real_GDP                      7.94
# Unemployment_Rate             0.83
# DROUGHT_ANNUAL_MEAN_INDEX     0.00
# damage_hurricane              0.00
# injuries_hurricane            0.00
# deaths_hurricane              0.00
# FIRE_SIZE                     0.00
# FIRE_FREQUENCY                0.00
# row_id                        0.00
# row_id                        0.00
# FLOOD_DURATION_HOURS          0.00
# FLOOD_PROPERTY_DAMAGE         0.00
# FLOOD_FREQUENCY               0.00
# STATE                         0.00
# index_nsa                     0.00
# hpi_yoy                       0.00
# yr                            0.00
# county_fips5                  0.00
# HEAT_STRESS_INDEX             0.00
# dtype: float64

# %%
df = climate_gdp_unemployment_tax_population

# ---------- 1. DISTINCT COUNTIES WITH MISSING prop_rate / population ----------

n_counties_missing_prop = df.loc[df["prop_rate"].isna(), "county_fips5"].nunique()
n_counties_missing_pop  = df.loc[df["population"].isna(), "county_fips5"].nunique()

print("Distinct counties missing prop_rate:", n_counties_missing_prop)
print("Distinct counties missing population:", n_counties_missing_pop)

# ---------- 2. MISSING COUNTS BY YEAR ----------

missing_prop_by_year = (
    df.groupby("yr")["prop_rate"]
      .apply(lambda s: s.isna().sum())
      .reset_index(name="n_missing_prop_rate")
)

missing_pop_by_year = (
    df.groupby("yr")["population"]
      .apply(lambda s: s.isna().sum())
      .reset_index(name="n_missing_population")
)

print(missing_prop_by_year)
print(missing_pop_by_year)

# ---------- 3. MISSING COUNTS BY COUNTY ----------

missing_prop_by_county = (
    df.groupby("county_fips5")["prop_rate"]
      .apply(lambda s: s.isna().sum())
      .reset_index(name="n_missing_prop_rate")
)

missing_pop_by_county = (
    df.groupby("county_fips5")["population"]
      .apply(lambda s: s.isna().sum())
      .reset_index(name="n_missing_population")
)

print(missing_prop_by_county.head())   # or .sort_values("n_missing_prop_rate", ascending=False)
print(missing_pop_by_county.head())
# Out:
# Distinct counties missing prop_rate: 977
# Distinct counties missing population: 1046
#       yr  n_missing_prop_rate
# 0   2000                  918
# 1   2001                  881
# 2   2002                  845
# 3   2003                  313
# 4   2004                  196
# 5   2005                  175
# 6   2006                  171
# 7   2007                  133
# 8   2008                  138
# 9   2009                  107
# 10  2010                  102
# 11  2011                  107
# 12  2012                   88
# 13  2013                  159
# 14  2014                  183
# 15  2015                  186
# 16  2016                  731
# 17  2017                  766
# 18  2018                  783
# 19  2019                  820
# 20  2020                  840
#       yr  n_missing_population
# 0   2000                  1045
# 1   2001                  1046
# 2   2002                  1046
# 3   2003                    10
# 4   2004                    10
# 5   2005                    10
# 6   2006                    10
# 7   2007                    10
# 8   2008                    10
# 9   2009                    10
# 10  2010                  1046
# 11  2011                    10
# 12  2012                    10
# 13  2013                    10
# 14  2014                    10
# 15  2015                    10
# 16  2016                    10
# 17  2017                    10
# 18  2018                    10
# 19  2019                    10
# 20  2020                  1046
#   county_fips5  n_missing_prop_rate
# 0        01001                    8
# 1        01003                    8
# 2        01007                    8
# 3        01009                    8
# 4        01015                    8
#   county_fips5  n_missing_population
# 0        01001                     5
# 1        01003                     5
# 2        01007                     5
# 3        01009                     5
# 4        01015                     5

# %%
df = climate_gdp_unemployment_tax_population

# ----- counties with prop_rate missing for ALL years -----
all_missing_prop = (
    df.groupby("county_fips5")["prop_rate"]
      .apply(lambda s: s.isna().all())
      .reset_index(name="all_missing_prop_rate")
)

n_counties_all_missing_prop = all_missing_prop["all_missing_prop_rate"].sum()
print("Counties with prop_rate missing for ALL years:", n_counties_all_missing_prop)

# optionally list them
counties_all_missing_prop = all_missing_prop.loc[
    all_missing_prop["all_missing_prop_rate"], "county_fips5"
].tolist()
print("county_fips5 with prop_rate missing for all years:", counties_all_missing_prop)


# ----- counties with population missing for ALL years -----
all_missing_pop = (
    df.groupby("county_fips5")["population"]
      .apply(lambda s: s.isna().all())
      .reset_index(name="all_missing_population")
)

n_counties_all_missing_pop = all_missing_pop["all_missing_population"].sum()
print("Counties with population missing for ALL years:", n_counties_all_missing_pop)

counties_all_missing_pop = all_missing_pop.loc[
    all_missing_pop["all_missing_population"], "county_fips5"
].tolist()
print("county_fips5 with population missing for all years:", counties_all_missing_pop)
# Out:
# Counties with prop_rate missing for ALL years: 80
# county_fips5 with prop_rate missing for all years: ['02020', '02090', '02170', '09110', '09120', '09130', '09140', '09170', '09180', '09190', '15005', '21003', '21007', '21015', '21017', '21019', '21023', '21029', '21031', '21037', '21039', '21043', '21047', '21049', '21059', '21061', '21067', '21077', '21081', '21089', '21093', '21103', '21111', '21113', '21117', '21123', '21127', '21139', '21145', '21149', '21163', '21179', '21185', '21191', '21209', '21211', '21215', '21221', '21227', '21239', '29189', '29510', '37129', '40017', '40027', '40031', '40033', '40037', '40047', '40051', '40081', '40083', '40087', '40109', '40111', '40113', '40117', '40131', '40135', '40143', '40145', '42011', '42051', '42073', '42075', '42077', '42079', '47057', '47173', '51067']
# Counties with population missing for ALL years: 10
# county_fips5 with population missing for all years: ['02020', '02090', '02170', '09110', '09120', '09130', '09140', '09170', '09180', '09190']
