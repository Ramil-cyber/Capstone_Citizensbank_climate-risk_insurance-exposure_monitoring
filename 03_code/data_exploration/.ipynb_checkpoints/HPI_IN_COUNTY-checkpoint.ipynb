# %%
import pandas as pd

# %%
hpi = pd.read_csv(
    "../../01_original_data/federal_housing_finance_agency/hpi_master.csv"
)
hpi = hpi[
    (hpi["level"] == "MSA") & (hpi["yr"] >= 1999) & (hpi["yr"] <= 2020)
]  # only keep data for msa level
hpi = hpi[["place_name", "place_id", "yr", "period", "index_nsa"]]
hpi = hpi.groupby(["place_id", "yr"], as_index=False).agg(
    {
        "place_name": "first",
        "place_id": "first",
        "yr": "first",
        "index_nsa": "mean",
    }
)

hpi["index_prev"] = hpi.groupby(["place_id"])["index_nsa"].shift(1)
hpi["hpi_change"] = hpi["index_nsa"] - hpi["index_prev"]

hpi["yr"] = pd.to_numeric(hpi["yr"], errors="coerce")
hpi["index_nsa"] = pd.to_numeric(hpi["index_nsa"], errors="coerce")

hpi["hpi_yoy"] = (hpi["index_nsa"] / hpi["index_prev"] - 1) * 100

hpi = hpi.dropna(subset=["hpi_yoy"])

hpi.sort_values(by=["place_id", "yr"])
# Out:
#        place_name place_id    yr  index_nsa  index_prev  hpi_change   hpi_yoy
# 1     Abilene, TX    10180  2000   115.7100    114.3075      1.4025  1.226954
# 2     Abilene, TX    10180  2001   120.4200    115.7100      4.7100  4.070521
# 3     Abilene, TX    10180  2002   123.8525    120.4200      3.4325  2.850440
# 4     Abilene, TX    10180  2003   127.0975    123.8525      3.2450  2.620052
# 5     Abilene, TX    10180  2004   132.7600    127.0975      5.6625  4.455241
# ...           ...      ...   ...        ...         ...         ...       ...
# 9014     Yuma, AZ    49740  2016   171.2425    164.9825      6.2600  3.794342
# 9015     Yuma, AZ    49740  2017   177.8425    171.2425      6.6000  3.854183
# 9016     Yuma, AZ    49740  2018   184.3200    177.8425      6.4775  3.642268
# 9017     Yuma, AZ    49740  2019   193.8850    184.3200      9.5650  5.189345
# 9018     Yuma, AZ    49740  2020   207.5775    193.8850     13.6925  7.062176
#
# [8609 rows x 7 columns]

# %%
xwalk = pd.read_csv(
    "../../01_original_data/federal_housing_finance_agency/list1_2023.csv"
)
xwalk.columns = (
    xwalk.columns.str.strip().str.lower().str.replace(r"\s+", "_", regex=True)
)
xwalk["county_fips5"] = (
    xwalk["fips_state_code"].astype(str).str.upper().str.strip().str.zfill(2)
    + xwalk["fips_county_code"].astype(str).str.zfill(3).str.strip()
)
xwalk = xwalk[
    [
        "cbsa_code",
        "cbsa_title",
        "county_fips5",
        "county/county_equivalent",
        "state_name",
    ]
]
xwalk["cbsa_code"] = xwalk["cbsa_code"].astype(str)
# xwalk.info()
xwalk
# Out:
#      cbsa_code      cbsa_title county_fips5 county/county_equivalent  \
# 0        10100    Aberdeen, SD        46013             Brown County
# 1        10100    Aberdeen, SD        46045           Edmunds County
# 2        10140    Aberdeen, WA        53027      Grays Harbor County
# 3        10180     Abilene, TX        48059          Callahan County
# 4        10180     Abilene, TX        48253             Jones County
# ...        ...             ...          ...                      ...
# 1910     49700   Yuba City, CA        06101            Sutter County
# 1911     49700   Yuba City, CA        06115              Yuba County
# 1912     49740        Yuma, AZ        04027              Yuma County
# 1913     49780  Zanesville, OH        39119         Muskingum County
# 1914     49820      Zapata, TX        48505            Zapata County
#
#         state_name
# 0     South Dakota
# 1     South Dakota
# 2       Washington
# 3            Texas
# 4            Texas
# ...            ...
# 1910    California
# 1911    California
# 1912       Arizona
# 1913          Ohio
# 1914         Texas
#
# [1915 rows x 5 columns]

# %%
hpi_county_level = xwalk.merge(
    hpi,
    left_on=["cbsa_code"],  # , "nri_ver"],
    right_on=["place_id"],  # , "yr"],
    how="inner",
).dropna(subset="hpi_yoy")

hpi_county_level["yr"] = hpi_county_level["yr"].astype(int)
hpi_county_level
# Out:
#       cbsa_code   cbsa_title county_fips5 county/county_equivalent state_name  \
# 0         10180  Abilene, TX        48059          Callahan County      Texas
# 1         10180  Abilene, TX        48059          Callahan County      Texas
# 2         10180  Abilene, TX        48059          Callahan County      Texas
# 3         10180  Abilene, TX        48059          Callahan County      Texas
# 4         10180  Abilene, TX        48059          Callahan County      Texas
# ...         ...          ...          ...                      ...        ...
# 21960     49740     Yuma, AZ        04027              Yuma County    Arizona
# 21961     49740     Yuma, AZ        04027              Yuma County    Arizona
# 21962     49740     Yuma, AZ        04027              Yuma County    Arizona
# 21963     49740     Yuma, AZ        04027              Yuma County    Arizona
# 21964     49740     Yuma, AZ        04027              Yuma County    Arizona
#
#         place_name place_id    yr  index_nsa  index_prev  hpi_change   hpi_yoy
# 0      Abilene, TX    10180  2000   115.7100    114.3075      1.4025  1.226954
# 1      Abilene, TX    10180  2001   120.4200    115.7100      4.7100  4.070521
# 2      Abilene, TX    10180  2002   123.8525    120.4200      3.4325  2.850440
# 3      Abilene, TX    10180  2003   127.0975    123.8525      3.2450  2.620052
# 4      Abilene, TX    10180  2004   132.7600    127.0975      5.6625  4.455241
# ...            ...      ...   ...        ...         ...         ...       ...
# 21960     Yuma, AZ    49740  2016   171.2425    164.9825      6.2600  3.794342
# 21961     Yuma, AZ    49740  2017   177.8425    171.2425      6.6000  3.854183
# 21962     Yuma, AZ    49740  2018   184.3200    177.8425      6.4775  3.642268
# 21963     Yuma, AZ    49740  2019   193.8850    184.3200      9.5650  5.189345
# 21964     Yuma, AZ    49740  2020   207.5775    193.8850     13.6925  7.062176
#
# [21965 rows x 12 columns]

# %%
hpi[hpi["place_id"] == "10100"]
# Out:
# Empty DataFrame
# Columns: [place_name, place_id, yr, index_nsa, index_prev, hpi_change, hpi_yoy]
# Index: []

# %%
# Not using this anymore because we have the new HPI in county level
# hpi_county_level.to_csv(
#     "../../02_processed_data/hpi_county_2000.csv",
#     index=False,
# )

# %%
hpi_county_level.columns
# Out:
# Index(['cbsa_code', 'cbsa_title', 'county_fips5', 'county/county_equivalent',
#        'state_name', 'place_name', 'place_id', 'yr', 'index_nsa', 'index_prev',
#        'hpi_change', 'hpi_yoy'],
#       dtype='object')

# %%
NEW_HPI_NO_CONVERSION = pd.read_excel("../../01_original_data/hpi_at_county.xlsx")

# %%
NEW_HPI_NO_CONVERSION.iloc[4:8]
# Out:
#   HPI for Counties (All-Transactions Index)\nExperimental Indexes Showing Cumulative (Nominal) Annual Appreciation  \
# 4                                              State
# 5                                                 AL
# 6                                                 AL
# 7                                                 AL
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3         Unnamed: 4 Unnamed: 5  \
# 4     County  FIPS code       Year  Annual Change (%)        HPI
# 5    Autauga      01001       1986                NaN        100
# 6    Autauga      01001       1987              -1.86      98.14
# 7    Autauga      01001       1988                2.6     100.68
#
#            Unnamed: 6          Unnamed: 7
# 4  HPI with 1990 base  HPI with 2000 base
# 5               95.54               70.81
# 6               93.76               69.49
# 7               96.19               71.29

# %%
NEW_HPI_NO_CONVERSION.columns = [
    "state_name",
    "county/county_equivalent",
    "county_fips5",
    "yr",
    "hpi_change",
    "index_nsa",
    "drop1",
    "drop2",
]

# %%
NEW_HPI_NO_CONVERSION.iloc[4:8]
# Out:
#   state_name county/county_equivalent county_fips5    yr         hpi_change  \
# 4      State                   County    FIPS code  Year  Annual Change (%)
# 5         AL                  Autauga        01001  1986                NaN
# 6         AL                  Autauga        01001  1987              -1.86
# 7         AL                  Autauga        01001  1988                2.6
#
#   index_nsa               drop1               drop2
# 4       HPI  HPI with 1990 base  HPI with 2000 base
# 5       100               95.54               70.81
# 6     98.14               93.76               69.49
# 7    100.68               96.19               71.29

# %%
NEW_HPI_NO_CONVERSION_ROI = NEW_HPI_NO_CONVERSION[
    [
        "state_name",
        "county/county_equivalent",
        "county_fips5",
        "yr",
        "hpi_change",
        "index_nsa",
    ]
].iloc[5:]

# %%
NEW_HPI_NO_CONVERSION_ROI.head()
# Out:
#   state_name county/county_equivalent county_fips5    yr hpi_change index_nsa
# 5         AL                  Autauga        01001  1986        NaN       100
# 6         AL                  Autauga        01001  1987      -1.86     98.14
# 7         AL                  Autauga        01001  1988        2.6    100.68
# 8         AL                  Autauga        01001  1989        4.3    105.02
# 9         AL                  Autauga        01001  1990      -0.33    104.67

# %%
NEW_HPI_NO_CONVERSION_ROI.to_csv(
    "../../02_processed_data/hpi_county_2000.csv",
    index=False,
)
