# %%
import pandas as pd

df = pd.read_stata("../../01_original_data/Financial Data/BJK_County_Tax_Panel_public.dta")

# %%
df_new = df[["fips", "year", "prop_rate"]]
df_new = df_new[(df_new["year"] >= 2000) & (df_new["year"] <= 2020)]
df_new.head()
# Out:
#    fips  year  prop_rate
# 0  1001  2000        NaN
# 1  1001  2001        NaN
# 2  1001  2002        NaN
# 3  1001  2003      0.245
# 4  1001  2004      0.245

# %%
df_new.to_csv("../../01_original_data/Financial Data/property_tax_cleaned.csv", index=False)
