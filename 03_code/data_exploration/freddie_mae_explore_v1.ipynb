# %%
import pandas as pd

# %%
freddie_mae = pd.read_parquet(
    "../../02_processed_data/freddie_mae_clean.parquet",
    engine="pyarrow",
)
freddie_mae.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388622 entries, 0 to 388621
# Data columns (total 42 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   reference_pool_id                        388622 non-null  int64
#  1   monthly_reporting_period                 388622 non-null  int64
#  2   channel                                  388622 non-null  object
#  3   seller_name                              388622 non-null  object
#  4   servicer_name                            387971 non-null  object
#  5   original_interest_rate                   388622 non-null  float64
#  6   current_interest_rate                    387971 non-null  float64
#  7   upb_at_issuance                          388622 non-null  float64
#  8   current_actual_upb                       388622 non-null  float64
#  9   original_loan_term                       388622 non-null  int64
# ...
