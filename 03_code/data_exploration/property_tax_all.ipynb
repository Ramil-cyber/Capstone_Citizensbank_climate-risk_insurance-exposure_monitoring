# %%
import pandas as pd

df = pd.read_stata("../../01_original_data/Financial Data/BJK_County_Tax_Panel_public.dta")

# %%
df_new = df[["fips", "year", "prop_rate"]]
df_new = df_new[(df_new["year"] >= 2000)]
df_new.head()

# %%
df_new.to_csv("../../01_original_data/Financial Data/property_tax_all.csv", index=False)
